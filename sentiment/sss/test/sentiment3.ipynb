# %% [markdown]
# ## Read into Python
#
# Let's first read the required data from CSV file using Pandas library.

# %%
import pandas as pd
import csv
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.utils import shuffle
from sklearn.feature_extraction.text import CountVectorizer
import numpy as np                  #linear algebra
import pandas as pd                 # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt     #For Visualisation
import seaborn as sns               #For better Visualisation
from bs4 import BeautifulSoup       #For Text Parsing

# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv('gold_3.csv')
data = data[['Dates','News','PriceSentiment']]
print(data.shape)
data.head(7)
# Out:
# (2500, 3)
#       Dates                                               News PriceSentiment
# 0  10/10/11  can make money on gold at these levels also: k...           none
# 1   13/6/17      Gold prices hold modest loss after PPI report       negative
# 2  12/12/16  gold jewellery sales pick up slowly after fall...       positive
# 3   22/9/16  Gold climbs to 2-week high on cautious Fed out...       positive
# 4  30/11/05          spot gold quoted at $492.30 in asia trade       positive
# 5   1/10/15            mcx gold december contract trades lower       negative
# 6    1/8/12          how top performers are going for the gold           none

# %% [markdown]
# Now, show the data how looks like…

# %%
data.isnull().sum()
# Out:
# Dates             0
# News              0
# PriceSentiment    0
# dtype: int64

# %%
data=data.dropna()
data.isnull().sum()
# Out:
# Dates             0
# News              0
# PriceSentiment    0
# dtype: int64

# %%
Sentiment = data['PriceSentiment'].unique()
print(Sentiment)

data.groupby(data['PriceSentiment']).News.count().plot.bar(ylim=0)
plt.show()
# Out:
# ['none' 'negative' 'positive' 'neutral']

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/whatbest/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
import re

stemmer = PorterStemmer()
words = stopwords.words("english")

data['processedtext'] = data['News'].apply(lambda x: " ".join([stemmer.stem(i) for i in re.sub("[^a-zA-Z]", " ", x).split() if i not in words]).lower())

# %%
print(data.shape)
data.head(10)
# Out:
# (2500, 4)
#       Dates                                               News PriceSentiment  \
# 0  10/10/11  can make money on gold at these levels also: k...           none
# 1   13/6/17      Gold prices hold modest loss after PPI report       negative
# 2  12/12/16  gold jewellery sales pick up slowly after fall...       positive
# 3   22/9/16  Gold climbs to 2-week high on cautious Fed out...       positive
# 4  30/11/05          spot gold quoted at $492.30 in asia trade       positive
# 5   1/10/15            mcx gold december contract trades lower       negative
# 6    1/8/12          how top performers are going for the gold           none
# 7   25/7/14       gold remains higher after durable-goods data       positive
# 8   27/7/17  Gold prices log highest finish since the middl...       positive
# 9  12/10/16  Gold futures waver in electronic trading after...           none
#
#                                        processedtext
# 0  make money gold level also kishor narn anand r...
# 1             gold price hold modest loss ppi report
# 2               gold jewelleri sale pick slowli fall
# 3           gold climb week high cautiou fed outlook
# 4                          spot gold quot asia trade
# 5               mcx gold decemb contract trade lower
# 6                                top perform go gold
# 7                gold remain higher durabl good data
# 8      gold price log highest finish sinc middl june
# 9          gold futur waver electron trade fed minut

# %% [markdown]
# ## Pre-process Data
#
# We need to remove package name as it's not relevant. Then convert text to lowercase for CSV data. So, this is data pre-process stage.

# %%
def preprocess_data(data):
    # Remove package name as it's not relevant
    #data = data.drop('News', axis=1)
    
    # Convert text to lowercase
    data['processedtext'] = data['processedtext'].str.strip().str.lower()
    return data

# %%
data = preprocess_data(data)

# %% [markdown]
# ## Splitting Data
#
# First, separate the columns into dependent and independent variables (or features and label). Then you split those variables into train and test set.

# %%
df = data
# Split into training and testing data
x = data['processedtext']
y = data['PriceSentiment']
x, x_test, y, y_test = train_test_split(x,y, stratify=y, test_size=0.25, random_state=42)

# %% [markdown]
# Vectorize text reviews to numbers.

# %%
# Vectorize text reviews to numbers
vec = CountVectorizer(stop_words='english')
x = vec.fit_transform(x).toarray()
x_test = vec.transform(x_test).toarray()

# %% [markdown]
# ## Model Generation
#
# After splitting and vectorize text reviews to number, we will generate a random forest model on the training set and perform prediction on test set features.

# %%
from sklearn.naive_bayes import MultinomialNB

model = MultinomialNB()
model.fit(x, y)
# Out:
# MultinomialNB()

# %% [markdown]
# ## Evaluating Model
#
# After model generation, check the accuracy using actual and predicted values.

# %%
model.score(x_test, y_test)*100
# Out:
# 75.36

# %% [markdown]
# Then check prediction…

# %%
from itertools import count
import pandas as pd
df = pd.read_csv('gold-dataset-sinha-khandait.csv', sep=',', header=None)
start = 7500
end = 10000
df = df[start - 1:end - 1]
correct = 0
for i in range(len(df)):
    print(df.values[i][2])
    print(model.predict(vec.transform([df.values[i][2]])),df.values[i][9] == model.predict(vec.transform([df.values[i][2]])))
    
    if df.values[i][9] == model.predict(vec.transform([df.values[i][2]])):
        correct += 1
        
print(correct / len(df) * 100 )
# Out:
# Gold futures decline to Rs 28,509 per 10 gm
# ['negative'] [ True]
# June gold gains $3.50, or 0.3%, to settle at $1,227.70/oz
# ['positive'] [ True]
# why it makes sense to buy gold
# ['positive'] [False]
# gold futures hit fresh high in electronic trading
# ['positive'] [ True]
# gold imports plunges to $650 million in august
# ['negative'] [False]
# gold strengthens as demand picks up
# ['positive'] [ True]
# gold, silver rise on global cues
# ['positive'] [ True]
# Gold futures steady near 1-week highs
# ['positive'] [False]
# gold prices extend weakness
# ['positive'] [False]
# Gold futures a tad up at Rs 27,030 per 10 gm
# ['positive'] [ True]
# gold, oil hold to losses after sentiment data
# ['negative'] [ True]
# Gold to edge lower on dwindling demand, central bank purchases
# ['negative'] [ True]
# gold prices move higher after u.s. data disappoints
# ['positive'] [ True]
# august gold rises $2.30 to $1,232.50/oz on globex
# ['negative'] [False]
# Gold futures notch fifth straight session gain
# ['positive'] [ True]
# Gold prices turn lower to settle at lowest since June
# ['negative'] [ True]
# Gold treads water as strong dollar offsets haven bids from Greek crisis
# ['negative'] [False]
# RBI against removing curbs on gold imports for now
# ['none'] [ True]
# gold, other metals fall as dollar rallies, stocks retreat
# ['negative'] [ True]
# Gold rises to Rs 28,630 on firm global cues, spot demand
# ['positive'] [ True]
# gold futures close lower, but off the session's lows
# ['negative'] [ True]
# gold hits record high of rs 29,265 on seasonal demand
# ['positive'] [ True]
# Gold reverses course to finish flat, shaking off stronger dollar
# ['negative'] [False]
# April gold down $2.10, or 0.2%, at $1,207.50/oz.
# ['negative'] [ True]
# iran gold demand at 4-year high
# ['positive'] [ True]
# Comex gold to test supports, rise
# ['positive'] [ True]
# bema gold updates russia kupol results
# ['none'] [ True]
# as chopard commits to using 100 per cent 'ethical' gold, what does that actually mean?
# ['positive'] [False]
# gold trades at 2-week high ahead of key yellen comments
# ['positive'] [ True]
# Gold falls back towards 5-1/2-year low after upbeat U.S. data
# ['negative'] [ True]
# april gold futures up $2.40 at $1,433.60 an ounce
# ['negative'] [False]
# gold futures revert to gains, up 0.5%
# ['positive'] [ True]
# December gold up 0.7% at $1,348.90/oz.
# ['positive'] [ True]
# gold futures settle higher for first time in 5 sessions
# ['positive'] [ True]
# Gold prices rise as United States-China trade tensions intensify
# ['positive'] [ True]
# Aug. gold climbs by $8.70, or 0.7%, to $1,268.70/oz
# ['negative'] [False]
# Gold prices finish at lowest level in over 2 weeks
# ['negative'] [ True]
# gold settles higher for first gain in four sessions
# ['positive'] [ True]
# june gold rises $6.70 to $1,234.50/oz on globex
# ['positive'] [ True]
# gold, silver trade lower on easing geopolitical tensions
# ['negative'] [ True]
# gold rate today: gold, silver lacklustre on low demand
# ['negative'] [ True]
# gold closes modestly lower, at $1,188.60/oz
# ['negative'] [ True]
# Akshaya Tritiya 2018 | Gold likely to test USD 1,500-1,550/oz in FY19: Himanshu Gupta
# ['positive'] [False]
# June gold settles at $1,268.10/oz, up $11.70, or 0.9%, for the session
# ['positive'] [ True]
# mcx goldguinea jan'13 contract gains
# ['positive'] [ True]
# gold perks up on global cues, jewellers' support
# ['negative'] [False]
# Gold marginally up in futures trade
# ['negative'] [False]
# gold down 2.7% in worst fall since dec 2013 on us jobs data
# ['negative'] [ True]
# gold, oil hold to gains after spain's budget plan
# ['positive'] [ True]
# gold rebounds on firm demand, silver slips further
# ['positive'] [ True]
# 2017 is the year gold drops below $1,000
# ['positive'] [False]
# gold inches higher ahead of us-japan trade talks
# ['positive'] [ True]
# gold settled down by 0.24% on monday
# ['positive'] [False]
# gold settles higher, recoups part of tuesday loss
# ['positive'] [ True]
# here's how you should trade gold and crude now
# ['negative'] [False]
# gold closes down more than $10
# ['positive'] [False]
# correct: kinross gold shares down 32c to $10.96
# ['none'] [ True]
# aug. gold settles up $3.20 at $654.40/ounce on nymex
# ['negative'] [False]
# gold futures rise over $10 an ounce in late morning dealings
# ['positive'] [ True]
# gold futures edge lower, but hold above $630
# ['negative'] [ True]
# internet gold to buy remaining shrs of goldtrade
# ['none'] [ True]
# feb gold closes at $549.30/oz, down 80c, or 0.2%
# ['negative'] [ True]
# Dec. gold at $1,283.90/oz after $1,282.90 Comex settlement
# ['positive'] [False]
# With 6% rise in demand, India remains top gold buyer
# ['positive'] [False]
# even small investors want to bite gold biscuits
# ['positive'] [False]
# Gold prices mark highest settlement in 2 weeks
# ['positive'] [ True]
# buy gold on dips: ashwani gujral
# ['positive'] [False]
# gold settles higher on safe-haven buying
# ['positive'] [ True]
# gold falls towards 2-week lows as trading starts to wind down
# ['positive'] [False]
# August gold climbs $2.20, or 0.2%, to settle at $1,249.10/oz
# ['negative'] [False]
# gold futures log largest 1-day dollar price gain since feb.
# ['positive'] [ True]
# Gold prices gain slightly in Asia with focus on U.S. jobs data
# ['positive'] [ True]
# gold closes down for third day, at low for 2012
# ['negative'] [ True]
# dec. gold up $5, or 0.4%, at $1,355.60/oz
# ['positive'] [ True]
# gold prices dull, trade under $474 in morning dealings
# ['positive'] [False]
# gold settles at $1,161.90/oz, highest since dec
# ['positive'] [ True]
# gold demand picks up in cities as price falls
# ['positive'] [False]
# August gold settles at $1,265.70/oz, down $5.70, or 0.5%
# ['negative'] [ True]
# gold rate today: gold, silver edge higher in morning trade
# ['positive'] [ True]
# Gold suffers biggest one-day percentage loss since Dec. 2013
# ['negative'] [ True]
# gold futures gain, turn higher for the week
# ['positive'] [ True]
# Gold ends higher, then falls as Fed hints as one more rate hike this year
# ['positive'] [False]
# metals issues, gold prices climb
# ['positive'] [ True]
# Gold prices gain in early Asia on uncertainty over next Fed move
# ['positive'] [ True]
# Gold to test resistance, dip
# ['negative'] [ True]
# Digital gold sellers hope trickle will become a rush
# ['none'] [ True]
# dec. gold up $7.10, ends at over 1-week high of $595.40/oz
# ['positive'] [ True]
# gold futures turn lower after july jobs data
# ['negative'] [ True]
# charts : gold price range vulnerable to fresh series of lower highs
# ['negative'] [False]
# Gold prices finish higher, but still logs a second-straight weekly loss
# ['positive'] [ True]
# show off as bling, get coloured highlights: indians are obsessed with gold
# ['positive'] [False]
# dec. gold up $20.50, or 1.2%, at $1.720.90/oz
# ['positive'] [ True]
# gold to trade in 28977-29305 range: achiievers equities
# ['negative'] [False]
# Wedding demand lifts gold prices to Rs 32,450
# ['positive'] [ True]
# gold prices close down $11 on week
# ['positive'] [False]
# gold prices fall as dollar gains vs yuan in escalating trade war
# ['negative'] [ True]
# spot buying of gold & silver picks up in indian markets
# ['negative'] [False]
# saudi, uae vat tax may squeeze gold jewellery demand even more
# ['positive'] [False]
# Gold futures top Rs 32,000
# ['positive'] [ True]
# Gold falls as investors turn to dollar for safety amid trade worries
# ['positive'] [False]
# spot gold at $321.40 in asia, down $4.1 from ny close
# ['positive'] [False]
# gold to trade in 28563-29053: achiievers equities
# ['negative'] [False]
# gold rate today: gold, silver bullish on rising demand, firm overseas trend
# ['none'] [False]
# June gold holds 0.3% at $1,287.70/oz.
# ['positive'] [False]
# 10 charts that show why gold is undervalued right now
# ['none'] [ True]
# gold prices drop for the session, but gain for the week
# ['positive'] [ True]
# gold slips as equities, dollar surge ahead of fed meet
# ['positive'] [False]
# gold futures remain up, climb 1.19% on positive global cues
# ['positive'] [ True]
# Feb. gold climbs $1.70, or 0.1%, to $1,187.20/oz
# ['negative'] [False]
# Gold settles higher for third day as investors await Trump-Xi meeting
# ['positive'] [ True]
# oil adds to gain, gold's lower after consumer data
# ['positive'] [False]
# Gold soars on fears Ukraine conflict poised to escalate
# ['positive'] [ True]
# gold futures remain lower after economic data
# ['negative'] [ True]
# factory orders keeps picture gloomy for gold, oil
# ['positive'] [False]
# Gold declines as rally to six-week high spurs selling
# ['positive'] [False]
# Profit-booking, weak global cues pull gold futures down to Rs 31,015
# ['negative'] [ True]
# Gold ticks lower in Asia ahead of Fed, Greece developments awaited
# ['negative'] [ True]
# 5 gold stocks favored by fund managers today
# ['none'] [ True]
# Silver scales 11-month high, gold rises as commodities rally
# ['positive'] [ True]
# gold futures lose more than $21 in three sessions
# ['negative'] [ True]
# mcx goldpetal oct contract trading firm
# ['positive'] [False]
# sell gold: ravindra rao
# ['none'] [ True]
# Gold prices pare some gains as data show rise in U.S. consumer sentiment
# ['positive'] [ True]
# anglogold ashanti revises higher gold production view
# ['positive'] [False]
# gold futures settle at highest level since oct. 30
# ['positive'] [ True]
# gold surges on safe-haven buying spree
# ['positive'] [ True]
# april gold futures slip below $917 an ounce
# ['negative'] [ True]
# gold futures heads higher after four-session loss
# ['positive'] [ True]
# gold futures climb more than $20 an ounce
# ['positive'] [ True]
# dubai : losing the lustre: gold jewellery demand seen at 20-yr low in uae
# ['negative'] [False]
# standard chartered : trade-war fears put floor under gold
# ['none'] [False]
# Gold pares gains after jobs report
# ['positive'] [ True]
# spot gold quoted at $422.30, up $1.80 from new york
# ['negative'] [False]
# feb gold up $1.10 at $457/oz in morning ny trade
# ['negative'] [False]
# gold edges up,but stays near 7-week low on fed rate hike outlook
# ['negative'] [False]
# gold, silver down on mild profit-taking
# ['negative'] [ True]
# dec gold down $4.10 at $377 an ounce
# ['positive'] [False]
# Gold inches higher as investors look ahead to U.S. data
# ['positive'] [ True]
# india may import record 300-400 tons of gold in apr-june: wgc
# ['none'] [ True]
# Gold climbs to 1-year high as U.S. dollar sees fresh weakness
# ['positive'] [ True]
# dec gold falls $2.60 to $495.70/oz after $502.30 overnight
# ['negative'] [ True]
# gold rate today: gold futures up rs 40 as participants create position
# ['positive'] [ True]
# Gold ticks higher after November jobs report
# ['positive'] [ True]
# Gold prices higher in Asia after ECB, U.S. jobs in focus
# ['positive'] [ True]
# Gold prices drop to six-month low on strong dollar, rate outlook
# ['negative'] [ True]
# gold futures hold above $357
# ['negative'] [False]
# gold stocks lift on a weaker dollar
# ['positive'] [ True]
# Gold slips on profit-taking, global cues
# ['negative'] [ True]
# Gold futures up at Rs 25,177 per 10 gm
# ['negative'] [False]
# gold rises by rs 195, silver up by rs 400 on festive demand
# ['positive'] [ True]
# gold down by 110 on poor demand; silver recovers by rs 500
# ['negative'] [ True]
# gold price-fixing scandal: uk's fca scrutinises $20 trillion gold market
# ['none'] [ True]
# randgold net falls despite rise in gold output
# ['none'] [ True]
# Gold hits 6-month peak on waning risk appetite
# ['positive'] [ True]
# Gold edges lower, palladium hits record high
# ['positive'] [False]
# gold rises to rs 22350, silver adds rs 550 on seasonal demand
# ['positive'] [ True]
# gold settles lower for fifth day as 'brexit' vote underway
# ['negative'] [ True]
# China's large imports lend solid support to gold prices
# ['negative'] [False]
# gold holds near 5-month low ahead of fed meeting outcome
# ['negative'] [ True]
# Gold futures end the week roughly 1.5% higher
# ['positive'] [ True]
# copper falls on china demand worries; gold dips
# ['none'] [False]
# Simone Biles wins vault, her third gold at Rio
# ['none'] [ True]
# gold fails to exceed $ 1,300 an ounce as the us dollar rallies
# ['positive'] [False]
# gold futures end the week with a gain of over $12
# ['positive'] [ True]
# gold sheds rs 340 in delhi on weak global cues, stronger rupee
# ['negative'] [ True]
# Gold prices settle lower to end 5-session climb
# ['negative'] [ True]
# cboe gold index declines by 1.4% to 135.01
# ['positive'] [False]
# gold futures join commodities rally
# ['none'] [False]
# gold at 3-week low as stocks, dollar surge on strong us gdp
# ['negative'] [ True]
# Gold futures settle higher after a two session decline
# ['positive'] [ True]
# dec. gold down $2.20 at $801/oz on nymex
# ['negative'] [ True]
# dec. gold climbs $2.50 to $626.30/oz in morning trading
# ['positive'] [ True]
# gold may trade in rs 27850-28100 range: nirmal bang
# ['negative'] [False]
# india : gold traders cheer as rupee gets stronger
# ['negative'] [False]
# dec. gold up $6.10, or 0.5%, at $1,367/oz
# ['positive'] [ True]
# etfs : n. american gold etf inflows up in march; europe saw outflows for second month -wgc
# ['negative'] [False]
# comex gold up 0.5% on day, gains 1.9% on week
# ['positive'] [ True]
# Dec. gold at $1,283.80/oz in electronic trade, after $1,283 Comex settlement
# ['positive'] [False]
# gold falls after four-session rise
# ['positive'] [False]
# feb. gold climbs $9.60, or 0.7%, to $1,332.10/oz after $1,333.80 high
# ['positive'] [ True]
# cboe gold index down 2.5% for week
# ['positive'] [False]
# gold spurts on good stockists buying, seasonal demand
# ['positive'] [ True]
# MCX GOLD December contract slips
# ['negative'] [ True]
# Gold logs 2.5% weekly rise
# ['positive'] [ True]
# sharps pixley:  gold signalling a $1,000 price rise - gundlach
# ['positive'] [ True]
# leveraged gold fund is the stupid investment of the week
# ['negative'] [False]
# Gold softens as dollar gains on U.S. data, Draghi comments
# ['positive'] [False]
# Gold prices settle at lowest in nearly two months
# ['negative'] [ True]
# Gold drops $10.50, or 0.9%, to $1,206.50 an ounce amid dollar strength
# ['negative'] [ True]
# april gold falls $5 to close at $667.30/oz in ny
# ['positive'] [False]
# june gold extends loss, down nearly 1% to $972.90
# ['negative'] [ True]
# gold lower on session, up on week
# ['negative'] [ True]
# Buy Comex gold if it dips to $1,109/ounce
# ['positive'] [False]
# Gold falls to Rs 29,115; silver down at Rs 39,050 per kg
# ['negative'] [ True]
# gold edges up as dollar eases; markets brace for fed meeting
# ['negative'] [False]
# gold decline amid speculation of indian demand falling
# ['negative'] [ True]
# gold futures close higher for first time in six session
# ['positive'] [ True]
# india : jewellery shares fall on fear of gold import curbs; titan down 4.73%
# ['negative'] [ True]
# mcx goldpetal jan'13 contract slips
# ['positive'] [False]
# gold futures catch a bid as stock futures fall
# ['negative'] [ True]
# Gold slips to fresh multi-week lows after Dudley's comments
# ['positive'] [False]
# mcx gold plunges 7.8% in june series so far
# ['positive'] [False]
# Gold prices settle at 2-week low, down about 1.9% for the week
# ['negative'] [ True]
# Gold turns higher by the settlement as U.S. dollar weakens
# ['positive'] [ True]
# cftc : cot gold, silver and us dollar index report - july 27, 2018
# ['negative'] [False]
# gold ends lower despite resurgent stock-market volatility
# ['negative'] [ True]
# gold falls as dollar gains, iran tensions ease
# ['positive'] [False]
# gold and silver poised for price spikes: analyst
# ['positive'] [ True]
# gold tumbles below rs 30,000 mark as intense selloff continues
# ['negative'] [ True]
# Dec. gold settles at $1,292.40/oz, up $9.50, or 0.7%
# ['positive'] [ True]
# Gold tumbles by Rs 300 on weak global cues, fall in demand
# ['negative'] [ True]
# etfs : gld sees gold holdings drop nearly 50 tonnes in 2018
# ['negative'] [ True]
# gold tops record, trades at $1,258.90
# ['positive'] [ True]
# gold shines as buyers flock to stores on akshaya tritiya
# ['none'] [ True]
# Gold slips in Asia as investors look to possible Yellen comments
# ['none'] [False]
# options converted into gold futures in first settlement
# ['negative'] [False]
# gold goes up rs 81 on positive global cues
# ['positive'] [ True]
# gold futures climb as much as $9; copper jumps
# ['positive'] [ True]
# is gold ready for a 'rocket shot'?
# ['positive'] [False]
# oil, gold advance before u.s. jobs data
# ['positive'] [ True]
# fed's bullard: oil and gold gains not inflationary
# ['positive'] [False]
# Gold futures log first gain in three sessions
# ['positive'] [ True]
# gold futures notch a nearly 1-week high
# ['positive'] [ True]
# gold hits near 1-year peak as tensions rise over n.korea
# ['positive'] [ True]
# gold gains for fourth session as tax bill fuels inflation expectations
# ['negative'] [False]
# December gold off 0.3% at $1,275.70/oz.
# ['positive'] [False]
# charts : daily inverted head and shoulder pattern takes gold to form a bottom at 1212??
# ['negative'] [False]
# gold prices little changed; shares fall
# ['negative'] [False]
# Gold prices end lower as Trump's election win boosts U.S. equities, dollar
# ['negative'] [ True]
# sharps pixley: gold demand growing as supply starts to fall
# ['negative'] [ True]
# April gold falls $1.90, or 0.2%, to settle at $1,200.70/oz
# ['negative'] [ True]
# Gold and silver post weekly losses after banner run for dollar
# ['negative'] [ True]
# gold extends losses after durable-goods data
# ['positive'] [False]
# gold, silver slip on profit selling, low demand
# ['negative'] [ True]
# gold loses rs 250 on us rate hike chances, now at 2-month low
# ['negative'] [ True]
# gold up on jewellers buying, global cues; silver weak
# ['negative'] [False]
# gold futures close at new highs atop $1,100/ounce
# ['positive'] [ True]
# December gold drops $9.50, or 0.7%, to $1,341.70 an ounce
# ['positive'] [False]
# Gold futures settle at a one-month low
# ['negative'] [ True]
# new lows ahead for mkt, gold may fall to rs 24,000: sukhani
# ['negative'] [ True]
# gold timers in denial
# ['positive'] [False]
# gold open interest hits record: cme
# ['positive'] [False]
# Gold futures rebound to Rs 25,930 on global cues
# ['positive'] [ True]
# feb. gold gains $19.90 to $1,616.50/oz
# ['negative'] [False]
# gold back at $1,600 an ounce, up 2.2%
# ['positive'] [ True]
# ig / sharps pixley : gold price holds value against a weaker dollar
# ['positive'] [False]
# Gold tallies three-session rise, but ends week flat
# ['positive'] [ True]
# Commodity outlook: Gold has resistance at Rs 30,755-30,775 levels
# ['negative'] [False]
# feb. gold up 20 cents to settle at $1,697/oz
# ['negative'] [False]
# june gold down $12.50, or 1%, to end at $1,283.40/oz
# ['positive'] [False]
# world gold council : gold 2048 - the next 30 years for gold
# ['none'] [ True]
# extorre gold leads canadian stocks higher
# ['positive'] [ True]
# gold futures close above $550 an ounce
# ['positive'] [False]
# Buy Comex gold if it touches $1,107-08/ounce
# ['positive'] [False]
# Gold edges higher as Asian shares slip
# ['positive'] [ True]
# gold futures edge lower in thin trading
# ['negative'] [ True]
# February gold down $2.20, or 0.2%, at $1,131.10/oz.
# ['positive'] [False]
# gold closes 1.4% higher at $1,386.10 an ounce
# ['positive'] [ True]
# expert views on copper, gold, crude, nickel. do you agree?
# ['none'] [ True]
# gold slides more than $25 as dollar rallies
# ['positive'] [False]
# Gold falls to Rs 31,540 on weak demand; silver recovers by Rs 60 per kg
# ['negative'] [ True]
# gold rallies as political worry creates safe-haven bid
# ['positive'] [ True]
# mcx goldguinea december contract trades higher
# ['positive'] [ True]
# mcx goldm april contract slips
# ['positive'] [False]
# td securities : trump's decision to weigh-in on fed policy is bullish for gold
# ['positive'] [False]
# gold ends off highs amid dollar gyrations
# ['positive'] [False]
# gold posts modest loss, down a second-straight day
# ['negative'] [ True]
# a bottoming of gold prices might be closer than you think
# ['negative'] [False]
# gold may be entering a golden age
# ['none'] [ True]
# Gold prices mark lowest settlement since Nov. 20
# ['negative'] [ True]
# after the gold rush
# ['none'] [ True]
# Weak US Dollar may support Gold, Silver: Angel Commodities
# ['negative'] [False]
# amex gold bugs index falls 3% to close at 330.6
# ['positive'] [False]
# gold rises on worries over gm, banks
# ['positive'] [ True]
# comex gold gives back much of previous day's gain
# ['positive'] [ True]
# Support for MCX Gold Dec at Rs 28300: Kotak Commodity
# ['negative'] [False]
# gold futures rise, but hold under $600 an ounce
# ['positive'] [ True]
# mcx goldm october contract slips
# ['positive'] [False]
# gold miners dehedge by 2 mln ounces: report
# ['positive'] [False]
# Gold prices finish higher ahead of Fed policy statement
# ['positive'] [ True]
# Gold prices higher in Asia after China HSBC PMI shows steady demand
# ['positive'] [ True]
# bill gross has reservations about gold
# ['positive'] [False]
# charts : gold's narrow trade; beware a cascade
# ['negative'] [False]
# imported gold to be watched at refinery level: mayaram
# ['positive'] [False]
# Gold logs worst daily loss in 10 weeks after stellar jobs report
# ['negative'] [ True]
# gold futures post sharp gains
# ['positive'] [ True]
# Gold prices down at Rs 29,350; silver edges up to Rs 38,370
# ['positive'] [False]
# gold shows its mettle
# ['positive'] [ True]
# Gold futures settle at a more than 3-week high ahead of Fed minutes
# ['positive'] [ True]
# June gold settles at $1,230/oz, up $2.30, or 0.2%
# ['positive'] [ True]
# gold slips in early dealings
# ['positive'] [False]
# gold edges higher as traders eye dollar
# ['positive'] [ True]
# gold extends win streak to 4 sessions on china currency move
# ['positive'] [ True]
# gold futures end the week with a 5.2% gain
# ['positive'] [ True]
# metals indexes end at 1-wk highs, mirror gold strength
# ['negative'] [False]
# high speculative positions in gold raise sell-off worries
# ['positive'] [ True]
# MCX GOLDGUINEA Oct contract up marginally
# ['positive'] [ True]
# can rising yields stop gold?
# ['negative'] [False]
# spot gold quoted at $707.10 in asia trade
# ['positive'] [ True]
# gold futures log lowest settlement since june 5
# ['negative'] [ True]
# gold futures settle at 7-week low
# ['negative'] [ True]
# cboe gold index falls 2.3% to close at 84.04
# ['positive'] [False]
# gold futures tallies four-session loss of $6.10/oz
# ['negative'] [ True]
# gold turns higher as oil prices rally, dollar weakens
# ['positive'] [ True]
# gold ends flat; traders gauge inflation
# ['negative'] [False]
# need fin instrument that people can choose over gold: iifl
# ['none'] [ True]
# august gold gains $13.70, or 1.5%, to $942/oz on nymex
# ['negative'] [False]
# gold futures jump after stronger-than-expected ppi
# ['positive'] [ True]
# feb. gold drops $11.80, or 0.9%, to settle at $1,340.30/oz
# ['negative'] [ True]
# dec. gold settles at $1,221.20/oz, down $4.10, or 0.3%
# ['positive'] [False]
# gold, silver rally on weaker dollar, stimulus talk
# ['positive'] [ True]
# cpm group : global gold investment seen rising for 5th year in 2018
# ['positive'] [False]
# april gold closes at $665.70/oz, up $2.70
# ['negative'] [False]
# april gold down $2.70, or 0.2%, at $1,149.70/oz on comex
# ['positive'] [False]
# south africa dismisses gold fields appeal
# ['none'] [ True]
# Gold futures down at Rs 28,983 per 10 gm
# ['negative'] [ True]
# gold and other metal futures fall in early trade
# ['negative'] [ True]
# Commerce Ministry wants tax sops for SEZs, removal of import curbs on gold
# ['none'] [ True]
# Gold futures down at Rs 29,465 per 10 gm
# ['negative'] [ True]
# gold rises as investors watch fed, elections
# ['negative'] [False]
# Gold slips lower amid U.S. rate hike speculation
# ['negative'] [ True]
# Gold hits 1-month high on investment buying; silver spurts
# ['positive'] [ True]
# gold kist hires adviser to help review strategic options
# ['none'] [ True]
# gold settles 2.2% higher at $1,857.50 an ounce
# ['positive'] [ True]
# Gold prices mark highest finish since Sept. 6
# ['positive'] [ True]
# gold falls below $910 on reduced safe-haven buying
# ['positive'] [False]
# gold futures retreat, but poised for a weekly gain
# ['positive'] [ True]
# friday will be historic day for gold
# ['negative'] [False]
# mcx gold february contract slips 1%
# ['negative'] [ True]
# gold ends lower after tug-of-war session
# ['negative'] [ True]
# gold to trade in 27380-27726 range: achiievers equities
# ['negative'] [False]
# Gold futures weaken by Rs 86/ 10 grams
# ['positive'] [False]
# february gold down $2.20, or 0.2%, at $1,279.90 an ounce
# ['positive'] [False]
# gold futures set to market fifth session of gains
# ['positive'] [ True]
# metals shares end lower despite gold futures strength
# ['negative'] [ True]
# gold futures up $3.00 at $1,178.00 an ounce
# ['positive'] [ True]
# gold futures climb as much as $23 an ounce
# ['positive'] [ True]
# Gold ends at more than 3-week high as U.S. equities, dollar decline
# ['positive'] [ True]
# gold hits 1-yr peak as dollar sags, n.korea concerns support
# ['positive'] [ True]
# gold falls for second day after jobless data
# ['negative'] [ True]
# gold futures close at a 4-session low; copper at record high
# ['positive'] [False]
# gold declines as us stimulus outlook curbs demand
# ['none'] [False]
# gold futures fall $9 to close at $1,377 per ounce
# ['negative'] [ True]
# gold futures turn lower as dollar gains ground
# ['negative'] [ True]
# Gold retreats as dollar index taps highest levels since mid-July
# ['positive'] [False]
# Antofagasta copper, gold production rises
# ['none'] [ True]
# Support for MCX Gold December at Rs 28000: Kotak Commodity
# ['negative'] [False]
# gold futures up $4.70 at $1,109.20 an ounce
# ['positive'] [ True]
# Buy Comex gold if it dips to $1,200-05/ounce
# ['positive'] [False]
# Gold retains solid gains after economic reports
# ['negative'] [False]
# dubai gold exchange volume rise 20% in may- june '06
# ['positive'] [False]
# Gold gains as Europe debt concern spurs demand
# ['positive'] [ True]
# Gold futures post modest loss as dollar strengthens
# ['negative'] [ True]
# dec. gold gains $7.60 to $1,365.40/oz on globex
# ['positive'] [ True]
# lowell: better to buy an m-16 than gold
# ['none'] [ True]
# gold hits 1-1/2-week high after greece deal
# ['positive'] [ True]
# gold books best string of gains in nearly 2 months
# ['positive'] [ True]
# Smart gains in gold prices
# ['positive'] [ True]
# improved current account deficit: gold import curbs to be eased
# ['none'] [ True]
# dec. gold climbs $6.80, or 0.6%, to settle at $1,228/oz
# ['positive'] [ True]
# Dazzling returns whet investors' appetite for gold
# ['positive'] [False]
# gold futures head higher after two-session decline
# ['positive'] [ True]
# gold rises to 7-week high with greece in focus
# ['positive'] [ True]
# gold ends quarter up 10.3%; march down 5.2%
# ['positive'] [ True]
# gold jumps $27.60, or 2.1%, to settle at $1,358 an ounce
# ['positive'] [ True]
# December gold ends 0.2% higher at $1,294.80 an ounce
# ['positive'] [ True]
# gold futures fall; mining shares mixed
# ['negative'] [ True]
# Gold climbs for 4th straight week as dollar softens
# ['positive'] [ True]
# Gold futures ends lower after two session climb
# ['negative'] [ True]
# December gold down 0.7% at $1,311/oz.
# ['positive'] [False]
# Gold futures log sixth-straight weekly loss
# ['negative'] [ True]
# cboe gold index falls 3%, ends at 5-wk low of 127.6
# ['negative'] [ True]
# india : gold demand shines! yellow metal hits 6-year high on global equity selloff, festive buzz
# ['positive'] [False]
# gold prices end at four-session high
# ['positive'] [ True]
# gold shines as bulls bet on trump's favorite metal
# ['none'] [False]
# Gold Prices Slip Lower Despite U.S. Data
# ['negative'] [ True]
# dec. gold up $5.70 at $793.50 an ounce after fed cuts rates
# ['positive'] [ True]
# gold rises to record high, breezes past $1,400
# ['positive'] [ True]
# Gold prices mark lowest finish since May 24
# ['negative'] [ True]
# india's june gold imports drop by a quarter as rupee hits record low
# ['negative'] [ True]
# gold to hit high of rs 32,000 by diwali: kothari
# ['positive'] [ True]
# gold ends 0.2% higher at $1,734.90 an ounce
# ['positive'] [ True]
# gold rises as dollar weakens, making ninth yearly gain
# ['positive'] [ True]
# gold heads lower in last moments of pit trading
# ['negative'] [ True]
# sell everything else in rally and buy gold: trader
# ['none'] [ True]
# Gold futures settle nearly 3% lower on Fed-induced dollar rally
# ['negative'] [ True]
# Gold futures climb Rs 279 on global cues
# ['positive'] [ True]
# Buy, sell gold instantly on Paytm
# ['none'] [ True]
# gold prices fall further
# ['negative'] [ True]
# february gold slips $1.90, or 0.1%, at $1,172/oz.
# ['positive'] [False]
# december gold settles down 1.3% at $1,885./oz.
# ['positive'] [False]
# Dec. gold down $2, or 0.2%, to $1,290.40/oz after earlier highs above $1,300
# ['positive'] [False]
# gold at five-week high leads to profit-booking
# ['positive'] [ True]
# comex gold logs first gain in six sessions
# ['positive'] [ True]
# dec. gold falls $3.10 to $589.70/oz in morning trading
# ['positive'] [False]
# Dec. gold settles at $1,357.50/oz, up $16.30, or 1.2%, for the session
# ['positive'] [ True]
# sell mcx gold apr fut for target of rs 30420: fortune fin
# ['none'] [ True]
# harmony gold mining first-half profit falls 25%
# ['negative'] [ True]
# Gold prices hold steady ahead of US elections
# ['negative'] [False]
# an ounce of gold has always cost the same as a suit, here's why
# ['none'] [ True]
# Gold stretches streak of gains to a third session
# ['positive'] [ True]
# gold futures hold onto a gain of 0.6% for the week
# ['positive'] [ True]
# Gold prices down in Asia with geopolitical events watched
# ['positive'] [False]
# Gold futures settle lower for a fourth straight session
# ['negative'] [ True]
# correct:gold settles down $1.50 at $1,564.20/oz
# ['positive'] [False]
# Gold futures dips on profit-booking, global cues
# ['negative'] [ True]
# gold rebounds on renewed demand, seasonal support
# ['negative'] [False]
# june gold up $2.10 at $673.30 an ounce on nymex
# ['positive'] [ True]
# gold gains as floor trading reopens
# ['none'] [False]
# dhanteras buying fails to lift gold
# ['negative'] [False]
# gold prices pare losses, hold steady with u.s. politics in focus
# ['positive'] [False]
# dhanteras gold sales fall 30%; heavy discounts fail to lure buyers
# ['negative'] [ True]
# dec. gold ends down 1.1% at $1,174.20 an ounce
# ['positive'] [False]
# dhanteras demand pushes up gold by rs 100, silver by rs 300
# ['positive'] [ True]
# gold etf rallies to record high
# ['positive'] [ True]
# gold futures climb as dollar falls
# ['positive'] [ True]
# Dec. gold at $1,331.60/oz vs. settlement at $1,334.50
# ['negative'] [False]
# spot gold trading at $381.10 an ounce - kitco
# ['positive'] [ True]
# gold gains, heads for second straight weekly gain
# ['positive'] [ True]
# we are bullish on gold for intraday: naveen mathur, angel
# ['none'] [False]
# innovaminex, the cryptocurrency startup for precious metals traceability, to release a collection of cryptocurrency coins in gold and silver
# ['positive'] [False]
# gold slides on deflation worry after us jobs data
# ['positive'] [False]
# Gold futures prices trade near the session's high
# ['positive'] [ True]
# Gold lower after ADP payrolls-report
# ['negative'] [ True]
# aug. gold up $6.20, or 0.5%, to end at $1,260.10/oz
# ['negative'] [False]
# june gold last up 1.4%, or $9.10, at $678.80/oz in ny
# ['positive'] [ True]
# Gold settles lower, then seesaws after Fed meeting minutes
# ['negative'] [ True]
# gold futures end lower with traders on dollar watch
# ['negative'] [ True]
# gold weakens on lack of support; silver up
# ['negative'] [False]
# Gold futures settle lower, log weekly loss
# ['negative'] [ True]
# april gold up $1.40, or 0.1%, at $1,236/oz.
# ['negative'] [False]
# iran is planning new fx rules - says will allow unlimited hard currency, gold into country
# ['none'] [ True]
# feb. gold gains $1.40 to $1,599.30/oz
# ['negative'] [False]
# cftc : gold speculators added to their bets, now bearish for 6 straight weeks
# ['negative'] [False]
# gold futures settle at lowest since feb. 2011
# ['negative'] [ True]
# gold, silver slip in morning trade
# ['negative'] [ True]
# december gold up 0.4% at $1,296.90/oz.
# ['positive'] [ True]
# drinking gold was a grisly anti-aging trend of 16th-century france
# ['negative'] [False]
# Gold plunges to Rs 29,550; silver falls to Rs 41,500
# ['positive'] [False]
# gold prices bounce back in futures trade on global cues
# ['positive'] [ True]
# gold sinks below $1,700; silver dives more than 4%
# ['positive'] [False]
# gold trades below one-month high as europe data curbs demand
# ['positive'] [False]
# dec. gold settles at $1,344.70/oz , up $13.30, or 1%
# ['positive'] [ True]
# gold to trade in 26855-27159 range: achiievers equities
# ['negative'] [False]
# debt cycles and gold
# ['positive'] [False]
# gold drops on news that iraq will allow spy flights
# ['positive'] [False]
# feb. gold falls $1.50 to close at $643.20/oz
# ['positive'] [False]
# gold futures jump $18.60 to $1,384.60 an ounce
# ['positive'] [ True]
# gold prices still lower but within range of a 1-month peak
# ['positive'] [False]
# gold hits new high at rs 29,490 on seasonal demand
# ['positive'] [ True]
# meridian gold avg daily volume 1.01m shares
# ['none'] [ True]
# june gold trades at $1,226.70/oz, up $4.70, or 0.4%
# ['positive'] [ True]
# gold steadies above &#36;1,748 after greek debt deal
# ['negative'] [False]
# Gold futures post 2.5% monthly rise in July
# ['positive'] [ True]
# qe3 on cards; bet on gold, silver: finaport
# ['none'] [False]
# gold futures close lower as dollar rebounds
# ['negative'] [ True]
# gold drops $22, but scores over 6% monthly gain
# ['positive'] [ True]
# gold down 6.38% from lifetime high on other investor options
# ['positive'] [False]
# kazakhmys to buy eurasia gold for c$288 mln in cash
# ['positive'] [False]
# gold futures rise for first day in five as dollar falls
# ['positive'] [ True]
# gold may scale up to rs 30000 per 10 grams by diwali: industry
# ['negative'] [False]
# NCDEX opens gold delivery centre in Hyderabad
# ['positive'] [False]
# gold gains ground in electronic trade after fomc
# ['negative'] [False]
# Gold loses ground after market shrugs off housing data
# ['positive'] [False]
# Gold extends gains in wake of jobs report
# ['negative'] [False]
# gold falls on speculation financial crisis may have bottomed
# ['positive'] [False]
# spot gold prices up $3 at $941.20 a troy ounce
# ['positive'] [ True]
# June gold edges up by $1.50, or 0.1%, to settle at $1,257/oz
# ['positive'] [ True]
# gold dips in asia as dollar fortunes eyed ahead of us jobs data
# ['positive'] [False]
# gold futures up $2.00 at $1,022.20 an ounce
# ['positive'] [ True]
# gold futures settled at a nearly 17-month high, but under $1,300/oz
# ['positive'] [ True]
# Silver falls on reduced offtake; gold holds steady
# ['positive'] [False]
# Gold gains as dollar slides on disappointing consumer confidence report
# ['positive'] [ True]
# spot gold quoted at $677 in asia trade
# ['positive'] [ True]
# Near-term outlook is bullish for MCX gold
# ['none'] [False]
# gold prices climb closer to session highs ahead of comex settlement
# ['positive'] [ True]
# gold settles lower t $1,152.90 an ounce
# ['negative'] [ True]
# WGC to form panel for setting up spot gold exchange in India
# ['none'] [ True]
# correct: gold, silver futures close at one-week highs
# ['positive'] [ True]
# Gold futures ends lower for a second straight session
# ['negative'] [ True]
# april gold at $345.10/oz, down $7.10 after $343.50 low
# ['negative'] [ True]
# china : gold shines as wealth boosts jewelry
# ['none'] [False]
# firm gold prices help gold edged funds
# ['positive'] [False]
# gold futures score five session gains in a row
# ['positive'] [ True]
# gold futures hold near 8-month lows on fed speculation
# ['positive'] [False]
# india's gold imports see surprise spike in july-august
# ['positive'] [False]
# Gold dips as investors opt for safe-haven dollar, bonds
# ['positive'] [False]
# gold for june delivery ends down $15 at $921.50 an ounce
# ['positive'] [False]
# murenbeeld : now is not the time to sell gold
# ['none'] [ True]
# Gold rises to Rs 31,100; silver holds steady at Rs 39,900
# ['positive'] [ True]
# gold closes at 4-month high on swiss shock
# ['positive'] [ True]
# june gold down 40 cents to settle at $1,295.90/oz
# ['positive'] [False]
# gold prices gain in early asia as indian festival season approaches
# ['positive'] [ True]
# spot gold quoted at $534.90 in asia trade
# ['positive'] [ True]
# Gold slides; safe-haven bids retreat as dollar, stocks climb
# ['positive'] [False]
# merrill sees gold trade in $370-390 range in near term
# ['positive'] [False]
# gold moves below settlement price in electronic trade after fomc minutes
# ['negative'] [ True]
# asahi refining licenses emergent technology's responsible gold supply chain application
# ['none'] [ True]
# gold to peak over &#36;2,000/oz late 2012 or early 2013
# ['positive'] [ True]
# Gold falls from 1-week high after jobless claims data, Draghi comments
# ['positive'] [False]
# sell crude & gold: aurobinda gayan
# ['none'] [ True]
# gold holds above $1,200 as dollar adds to weekly decline
# ['positive'] [False]
# June gold traded at $1.265.30 ahead of data
# ['positive'] [False]
# gold futures climb past $900 for first time in six weeks
# ['positive'] [ True]
# Gold falls by Rs 200 on weak global cues, muted demand
# ['negative'] [ True]
# fitch : global gold output to rise during the next four years
# ['positive'] [False]
# Gold nudges up amid looming US tariffs on China
# ['negative'] [False]
# Gold slips, but safe-haven demand keeps prices above $1,300
# ['positive'] [False]
# april gold up $18.90, or 1.1%, to end at $1,681.60
# ['negative'] [False]
# remain bearish on gold & silver: motilal oswal
# ['negative'] [False]
# gold dips on upbeat spending, factory data
# ['negative'] [ True]
# february gold drops $14, or 1.1%, to $1,238/oz
# ['positive'] [False]
# gold prices jump to 1-month high
# ['positive'] [ True]
# gold ends lower after rising past $561
# ['negative'] [ True]
# silver hits four-year lows, gold snaps losing streak
# ['positive'] [ True]
# december rate hike worries sink gold to 7-week lows
# ['positive'] [False]
# gold ends april with modest monthly gain
# ['positive'] [ True]
# Gold locked below $1,300 as market braces for US Fed decision
# ['positive'] [False]
# gold rises as dollar falls ahead of fed announcement
# ['negative'] [False]
# June gold settles at $1,267.20/oz, down $10.30, or 0.8%
# ['positive'] [False]
# gold up 0.5% on day, gains almost 0.9% on week
# ['positive'] [ True]
# metal mania buying keeps silver, gold too hot
# ['none'] [ True]
# Gold prices turn lower as geopolitical tensions ease
# ['negative'] [ True]
# spot gold quoted at $474.90 in asia trade
# ['positive'] [ True]
# gold falls more than $9 as dollar, stocks climb
# ['positive'] [False]
# how much income tax you should pay on investments in gold?
# ['negative'] [False]
# gold drops over $20 in last hour of comex trade
# ['positive'] [False]
# Gold surges to Rs 31,850; silver jumps by Rs 360/kg
# ['negative'] [False]
# Gold prices ease in Asia on expectations of Fed taper continuing
# ['negative'] [False]
# sbi attracts deposits of 548 kg gold in two months
# ['negative'] [False]
# eldorado gold withdraws bid for andean resources
# ['positive'] [False]
# Gold inches higher as US-China trade optimism pressures dollar
# ['positive'] [ True]
# Feb. gold settles at $1,193.80/oz, up $12.80, or 1.1%
# ['negative'] [False]
# gold could hit $1,500, say merrill analysts
# ['positive'] [False]
# gold futures top $1,650 in electronic trading
# ['positive'] [ True]
# Gold prices fall the day, but post a third straight weekly gain
# ['negative'] [False]
# Gold slips further; silver sinks on speculative selling
# ['positive'] [False]
# Gold, Silver may trade with positive bias today: Angel
# ['positive'] [ True]
# feb. gold climbs $12.40, or 0.9%, to settle at $1,334.90/oz
# ['negative'] [False]
# Gold prices snap back after longest weekly losing streak in 12 years
# ['negative'] [False]
# gold futures gain more ground ahead of comex close
# ['positive'] [ True]
# 7im drops gold and adopts general commodities strategy
# ['positive'] [False]
# demand for gold real, price rise not a bubble: quantum mf
# ['none'] [False]
# Gold settles lower following November rout as dollar wavers
# ['negative'] [ True]
# Gold suffers largest one-day percentage loss in 5 weeks
# ['negative'] [ True]
# Gold hits 1-month peak as Trump's healthcare failure hurts dollar
# ['positive'] [ True]
# Gold price pulls back from 3-week high to settle lower
# ['positive'] [False]
# gold rises after bernanke talks about us jobs
# ['positive'] [ True]
# gold futures hold above $380
# ['negative'] [False]
# Gold adds to steep early loss after economic reports
# ['negative'] [ True]
# spot gold quoted at $383.60, down 0.18% from ny
# ['positive'] [False]
# Gold inches down, resurgent trade worries offer support
# ['none'] [False]
# metals focus :  gold demand tipped to firm just 1 per cent in 2018
# ['positive'] [False]
# gold at two-week low, on track for biggest weekly loss in about a month
# ['negative'] [ True]
# Gold in India shifts to discount, while China buying picks up
# ['none'] [False]
# Gold futures settle at highest level in nearly two weeks
# ['positive'] [ True]
# gold futures continue higher, but off session's high
# ['positive'] [ True]
# Gold wins the 2011 returns chase; beats all asset classes
# ['none'] [False]
# Dec. gold gains $7.60, or 0.6%, to settle at $1,296.50/oz
# ['positive'] [ True]
# Gold posts strongest weekly gain since mid-April
# ['positive'] [ True]
# record gold prices fail to dampen buying spirit
# ['positive'] [False]
# gold futures close above $473
# ['positive'] [ True]
# Gold settles at 2-month low on firmer dollar, rate-hike expectations
# ['negative'] [ True]
# gold stocks regain strength at close
# ['positive'] [ True]
# Gold sales in China slows
# ['negative'] [False]
# august gold gains after ppi data, last up 50 cents
# ['negative'] [False]
# august gold gains 20 cents to settle at $1,270.70/oz
# ['negative'] [False]
# Rising holdings in funds set to help gold gleam
# ['positive'] [False]
# gold prices end lower, but tally a second straight monthly gain
# ['negative'] [False]
# june gold falls $12.40, or 0.9%, to settle at $1,306.80/oz
# ['positive'] [False]
# Dec. gold gains $2.50, or 0.2%, to $1,226.80/oz
# ['positive'] [ True]
# Gold gains $16.50, or 1.4%, at $1,212.80/oz.
# ['positive'] [ True]
# Gold surges to Rs 29,550; silver reclaims Rs 39,000-mark
# ['negative'] [False]
# gold prices ease in asia in thin holiday trade
# ['positive'] [False]
# Increase in duty on gold may encourage illegal imports
# ['positive'] [False]
# charts : gold: the battle between the bulls and the bears continues
# ['positive'] [False]
# gold may top $800 within a week, analyst says
# ['positive'] [ True]
# gold quiet in low-volume trading
# ['negative'] [ True]
# goldcorp ceo sees 'quite a bit of runway' for gold prices
# ['none'] [ True]
# Gold prices little changed after housing, import data
# ['negative'] [False]
# how a gold miner turned a $1 million investment into $3 billion
# ['none'] [ True]
# dec. gold down $1.80 to settle at $1,311.20/oz
# ['positive'] [False]
# Gold / Silver / Copper futures - weekly outlook: February 6 - 10
# ['none'] [ True]
# gold could extend gains on coordinated central banks rate cuts
# ['negative'] [False]
# Gold dips as US dollar, equities strengthen
# ['negative'] [ True]
# Gold futures climb to Rs 26,668 per 10 gm
# ['positive'] [ True]
# mcx goldm november contract declines
# ['positive'] [False]
# Gold futures trade lower ahead of Comex settlement
# ['negative'] [ True]
# gold closes lower after seesawing session
# ['negative'] [ True]
# Gold falls to Rs 29,800; silver slips below Rs 40,000-level
# ['positive'] [False]
# you must own gold or you will lose a third of your retirement savings
# ['negative'] [False]
# gold, silver futures close at lowest levels since october
# ['negative'] [ True]
# Randgold profit up 41% as gold production rises
# ['negative'] [False]
# Gold slips to Rs 31,450; silver down by Rs 300 per kg
# ['negative'] [ True]
# gold jewellery sales expected to double this akshaya tritiya
# ['none'] [ True]
# gold ends at two-week high, rallies on bernanke
# ['positive'] [ True]
# gold futures up 0.10% on global cues
# ['positive'] [ True]
# gold ends $2 shy of may record, silver up 5%
# ['positive'] [ True]
# december gold ends at $1,095.70, up 0.6%
# ['positive'] [ True]
# gold futures settle lower; copper drops nearly 4%
# ['negative'] [ True]
# gold drops to lowest settlement since june
# ['negative'] [ True]
# gold futures fall under $700; copper sets new records
# ['negative'] [ True]
# gold regains record levels of rs 20,600 on wedding demand
# ['positive'] [ True]
# gold prices heading for the longest bull market
# ['none'] [False]
# charts : gold analysis: support at 1199/1183, resistance at 1214/1217
# ['negative'] [False]
# quokka goes for olympic gold
# ['positive'] [False]
# Barrick Gold stock price target cut to $18 from $21 at RBC Capital
# ['none'] [ True]
# Gold futures finish at lowest level in more than a week
# ['negative'] [ True]
# gold futures pull back in morning trading on dollar strength
# ['negative'] [ True]
# gold prices fall as dollar extends gains
# ['negative'] [ True]
# sales of indian gold jewellery drop in the gulf
# ['negative'] [ True]
# gold closes down to post biggest weekly drop this year
# ['negative'] [ True]
# Gold futures jump to Rs 30,335 on firm global cues
# ['positive'] [ True]
# gold futures close near $1,035 as dollar rises
# ['positive'] [False]
# crude oil, gold higher after u.s. data
# ['positive'] [ True]
# Gold dips as dollar firms ahead of release of Fed minutes
# ['negative'] [ True]
# 99 cents only's jeff gold is named president
# ['positive'] [False]
# Gold ETFs record Rs 656 cr outflow in FY16; AUM down 8.5%
# ['positive'] [False]
# paulson holds spdr gold trust, ups gm stakes
# ['positive'] [False]
# gold stocks retreat from earlier gains
# ['positive'] [ True]
# Dec. gold down a dime at $1,224.40/oz
# ['positive'] [False]
# December gold pares loss after data, down 0.1% at $1,312.90/oz.
# ['negative'] [ True]
# scrap gold supply to halve in india as cash crunch bites
# ['none'] [ True]
# gold futures slip for a third session
# ['negative'] [ True]
# spot gold bid at $407.30 an ounce, down $3.20
# ['positive'] [False]
# This chart level could trip up gold's rally
# ['positive'] [False]
# india's still top importer of gold
# ['none'] [ True]
# Gold, silver spurt on fresh demand
# ['positive'] [ True]
# Gold prices down slightly in early Asia with market eyeing U.S. data
# ['positive'] [False]
# gold dips as dollar rallies
# ['positive'] [False]
# metals, miners stand out as spot gold rises, ftse gains
# ['negative'] [False]
# Gold rises, but set for longest monthly losing streak in 5-1/2 years
# ['positive'] [ True]
# gold-buying gets a day as bonus
# ['negative'] [False]
# Dec. gold down $1.10, or 0.1%, to $1,276.20/oz
# ['positive'] [False]
# gold prices fall for 6th straight week
# ['negative'] [ True]
# gold ends below $1,600, lowest since december
# ['negative'] [ True]
# gold & silver put in restricted list to curb rising imports from korea
# ['negative'] [False]
# Gold prices score a weekly gain of roughly 1.5%
# ['positive'] [ True]
# Gold futures decline to Rs 31,723 on profit-taking, global cues
# ['negative'] [ True]
# gold futures fall 0.50% on weak global cues
# ['negative'] [ True]
# MCX GOLD June contract trading higher
# ['positive'] [ True]
# Gold futures extend losses on global cues
# ['positive'] [False]
# gold holds gain after ecb's policy decision
# ['positive'] [ True]
# feb. gold down $25.70 or 1.5%, ends at $1,648.90
# ['negative'] [ True]
# Gold slips on euro zone retail sales report, U.S. trade data
# ['negative'] [ True]
# gold gains rs 350, silver rs 800 on good demand
# ['positive'] [ True]
# gold futures inch up ahead of u.s. data
# ['positive'] [ True]
# buy gold for long term: ashish shah
# ['positive'] [False]
# gold futures gain ground ahead of yellen speech
# ['positive'] [ True]
# Gold marks highest finish in nearly 11 weeks as U.S.-North Korea tensions return
# ['positive'] [ True]
# Gold prices down 2.7% for the month, but gain about 3.6% for the quarter
# ['positive'] [ True]
# Gold hits record high of Rs 31,035 on firm global cues
# ['positive'] [ True]
# august gold falls $1.20 to close at $675.10/oz in ny
# ['positive'] [False]
# gold falls, loses 3.7% for the week
# ['positive'] [False]
# India looks to lift ban on gold imports from S. Korea
# ['none'] [ True]
# india : government puts gold dore imports under restricted category
# ['none'] [ True]
# options : gold's rally to five-week highs has revived interest in call options
# ['positive'] [ True]
# gold falls as terror plot hits oil, lifts dollar
# ['positive'] [False]
# outlook on gold, silver, crude oil: angel broking
# ['none'] [ True]
# Gold holds slight gain as ECB leaves monetary policy unchanged
# ['positive'] [ True]
# gold futures, stocks rise as data prompts dollar slide
# ['positive'] [ True]
# Gold turns lower but will still snap worst weekly skid in 12 years
# ['negative'] [ True]
# gold ends 0.3% lower at $1,654.50 an ounce
# ['negative'] [ True]
# jim rogers may buy gold if price drops to $1,300
# ['positive'] [False]
# fxtm : strong dollar weigh gold amid rising trade tensions
# ['positive'] [False]
# ...
# ['positive'] [ True]
# Gold falls to Rs 31,400 on muted demand
# ['positive'] [False]
# anz sees gold heading toward $1,400 by year-end
# ['positive'] [ True]
# mining : investors want australia's gold producers to buy their u.s. rivals
# ['none'] [ True]
# december gold adds 60 cents to $1,247.10 an ounce
# ['positive'] [ True]
# gold futures poised for weekly gain
# ['positive'] [ True]
# registered gold at comex has practically vanished
# ['positive'] [False]
# spot gold quoted at $440.40 down 30c from new york
# ['negative'] [ True]
# contrarian investor prefers gold over oil
# ['negative'] [False]
# gold futures score 4-session gain of 5.4%
# ['positive'] [ True]
# Dec. gold climbs $3.30, or 0.3%, to $1,283/oz after $1,273.20 intraday low
# ['negative'] [False]
# Gold drops on U.S. data, Fed move to end stimulus
# ['negative'] [ True]
# dec gold closes at $410/oz, up $5 for the session
# ['positive'] [ True]
# Gold holds modest gain after JOLTs data show record climb
# ['positive'] [ True]
# Gold snaps 6-session losing streak to regain key level
# ['positive'] [ True]
# 220pm update: gold and oil climb after attacks
# ['positive'] [ True]
# gold remains in positive territory after u.s. data dump
# ['positive'] [ True]
# gold settles 2.7% lower at $1,594.80 an ounce
# ['negative'] [ True]
# goldcorp: 2007 gold production up 35% to 2.29 mln ounces
# ['none'] [ True]
# invest in gold for better & safe returns
# ['none'] [ True]
# gold slips as dollar holds firm after us jobs data
# ['positive'] [False]
# Stay out of MCX gold
# ['negative'] [False]
# gold plunges to the lowest in six months but you still cannot buy
# ['negative'] [ True]
# gold futures lose roughly 0.9% for the week
# ['negative'] [ True]
# gold at best in 2 weeks, regains safe-haven status
# ['positive'] [ True]
# gold rises to record; gains 6.3% in week
# ['positive'] [ True]
# Gold inches up to Rs 29,270; silver slips to Rs 42,400 per kg
# ['negative'] [False]
# bank of taiwan : gold prices could rebound middle of next year
# ['negative'] [False]
# mcx goldm april contract up 1%
# ['positive'] [ True]
# Gold recovers to Rs 30,510; silver recaptures Rs 41,000-mark
# ['negative'] [False]
# dec gold falls $2.60 to end at 5-wk low of $463.20/oz
# ['negative'] [ True]
# Gold futures fall to Rs 30,890 per 10 gm
# ['negative'] [ True]
# gold futures mark first decline in 5 sessions
# ['positive'] [False]
# Gold futures move lower after data show rise in Dec. U.S. ISM index
# ['positive'] [False]
# dec. gold closes down 3.5% for the week
# ['positive'] [False]
# gold futures up $9.40 at $877.90 an ounce
# ['positive'] [ True]
# gold declines by rs 25, silver by rs 600 on global cues
# ['positive'] [False]
# india gold posts record, scrap selling picks up
# ['positive'] [ True]
# buy gold with target of rs 30900/10gm: angel broking
# ['none'] [ True]
# gold continues to fall on profit-taking, silver also slips
# ['negative'] [ True]
# Dec. gold falls $7.20, or 0.6%, to settle at $1,270.50/oz
# ['positive'] [False]
# Gold gains more ground as ICE U.S. Dollar Index trades near session lows
# ['positive'] [ True]
# Gold, silver slip on reduced demand
# ['negative'] [ True]
# Gold regains 29K mark on fresh buying, silver marginally up
# ['positive'] [ True]
# gold trades lower in morning deals; silver up
# ['negative'] [ True]
# gold futures climb roughly 1.4% for the week
# ['positive'] [ True]
# Gold scores largest monthly gain since January
# ['positive'] [ True]
# gold futures end three-session losing streak
# ['positive'] [False]
# feb gold falls $1 to $577.70/oz in afternoon dealings
# ['negative'] [ True]
# comex : the self-feeding, short-covering rally in gold prices
# ['positive'] [False]
# the curious case of clay turning to gold
# ['none'] [ True]
# gold futures drop to two-week low
# ['negative'] [ True]
# Dec. gold falls $4.50, or 0.4%, to settle at $1,255.90/oz
# ['positive'] [False]
# dec. gold down nearly $18, or 1.2%, to 1,395.60/oz
# ['positive'] [False]
# Gold drops 4th day in a row as market weighs Fed comments on policy
# ['negative'] [ True]
# barrick gold up 3.2% in $xau
# ['none'] [False]
# Gold settles down $5.60, or 0.5%, at $1,233.30 an ounce
# ['positive'] [False]
# why silver could be the new gold
# ['positive'] [False]
# gold stretches losses on lower demand, silver recovers
# ['negative'] [ True]
# Gold firms after three days of losses as equities drop
# ['negative'] [ True]
# gold futures rise 1% as dollar falls sharply
# ['positive'] [ True]
# gold climbs to six-week high as european concerns spur demand
# ['positive'] [ True]
# government fixes sovereign gold bond rate at rs 2,866/gram
# ['positive'] [False]
# aug. gold down $15, or 1.1%, at $1,319.70/oz
# ['negative'] [ True]
# Gold prices fall slightly as outlook for faster US interest hikes weigh
# ['negative'] [ True]
# gold hits 11-week high, ends higher
# ['positive'] [ True]
# Gold prices end lower, give back nearly half of their recent rally
# ['negative'] [ True]
# gold falls on stronger dollar; silver gains
# ['negative'] [ True]
# gold gains slightly in asia with fed leadership changes eyed
# ['positive'] [ True]
# gold futures end higher, but below $1,800
# ['positive'] [ True]
# gold prices surge above 3-three week highs amid dollar weakness
# ['positive'] [ True]
# gold inches lower; silver falls roughly 1%
# ['negative'] [ True]
# Buy Comex gold if it touches $,1310/oz
# ['positive'] [False]
# Gold falls as dollar firms after China halts trade talks
# ['negative'] [ True]
# buy spot gold above usd 1707: geojit comtrade
# ['positive'] [False]
# goldman raises coverage view on gold to attractive
# ['none'] [ True]
# Gold recoups some of its losses from a day earlier
# ['negative'] [False]
# gold rises more than 1% to hit 3-week high as fed outlook supports
# ['positive'] [ True]
# gold posts slight gains, amid greek debt concerns and sell-off in china
# ['negative'] [False]
# gold etfs mushroom in india
# ['none'] [ True]
# gold futures climb near $1,378/oz on globex
# ['positive'] [ True]
# whither gold?
# ['positive'] [False]
# Gold prices mark lowest finish since Oct. 6
# ['negative'] [ True]
# but why do we buy gold on akshaya tritiya?
# ['none'] [ True]
# gold, silver slip; it's time to tread with caution
# ['negative'] [ True]
# Gold, Silver may trade with sideways bias:Angel Commodities
# ['positive'] [False]
# Gold settles at its lowest level in a week
# ['negative'] [ True]
# ghana : pmmc partners indian company to establish gold refinery
# ['negative'] [False]
# Commodity outlook: Gold upside likely stay capped at Rs 32,000
# ['negative'] [False]
# Global gold demand declines by 9% to 915 tonnes in Q3: WGC
# ['negative'] [False]
# Gold prices end at highest level since early June, up 0.5% for the week
# ['positive'] [ True]
# Gold holds losses after jobs report
# ['positive'] [False]
# dec. gold down 20 cents at $1,384.80/oz on globex
# ['positive'] [False]
# harmony gold retains merrill as co-advisor for gfi bid
# ['positive'] [False]
# gold steady around highest in nearly 7 weeks on n.korea tensions
# ['positive'] [ True]
# glamis: project gold reserves more than double to 9.98m ozs
# ['none'] [ True]
# should gold be part of every investment portfolio?
# ['none'] [ True]
# Gold spurts on RBI move, silver retraces 42K
# ['none'] [False]
# philadelphia gold & silver index gains 2.4%
# ['positive'] [ True]
# gold futures recoup a bit after losses
# ['positive'] [False]
# gold closes at lowest level in over three weeks
# ['negative'] [ True]
# india increases base import price of gold, silver
# ['none'] [ True]
# gold recovers on modest demand, silver declines
# ['positive'] [ True]
# philadelphia gold & silver index climbs 1.6%
# ['positive'] [ True]
# gold may not yield sparkling returns, yellow metal loses glitter with dollar gaining strength
# ['negative'] [ True]
# mcx gold feb contract trades lower
# ['negative'] [ True]
# Gold settles lower for first 3-session slump in three weeks
# ['negative'] [ True]
# gold futures edge lower in morning trade
# ['negative'] [ True]
# Gold steady as global growth, trade worries raise safe-haven demand
# ['positive'] [False]
# cad to widen to &#36;25 bn in fy17 on gold imports surge: report
# ['none'] [ True]
# commodity bets: trading tips for gold, crude & copper
# ['none'] [ True]
# Gold perks up ahead of wedding season buys
# ['positive'] [ True]
# gold prices rising without support of dollar
# ['negative'] [False]
# dec. gold settles at $1,196.20/oz, up $8.80, or 0.7%, for the session
# ['positive'] [ True]
# Gold prices trade near session highs after reports of missile test in North Korea
# ['positive'] [ True]
# april gold down $1.10, or 0.1%, at $1,576.90/oz
# ['negative'] [ True]
# should you bet on gold loan companies?
# ['none'] [ True]
# gold volatile as traders assess fed taper news
# ['negative'] [False]
# gold settles lower as market looks to fed cues
# ['negative'] [ True]
# gold, silver stocks end week lower
# ['negative'] [ True]
# gold steady ahead of u.k. auction
# ['negative'] [False]
# Bitcoin's rise may be like when 'paper money displaced gold,' says Goldman's CEO
# ['none'] [ True]
# dec. gold maintains slight losses after claims data
# ['positive'] [False]
# aug gold closes 3% lower for the week
# ['negative'] [ True]
# bourses eye brisk business in gold etfs tomorrow, waive off charges
# ['negative'] [False]
# glamis gold to buy western silver
# ['positive'] [False]
# jeff rhodes : gold bulls puzzled why metal hasn't performed amid tensions
# ['negative'] [False]
# Gold adds $4.40, or 0.4%, at $1,237.50/oz.
# ['positive'] [ True]
# gold for june delivery up $10.50, or 0.8%, to $1,313.50/oz
# ['positive'] [ True]
# gold slides lower with u.s. nonfarm payrolls on tap
# ['negative'] [ True]
# Gold steady amid Fed rate hike expectations
# ['negative'] [False]
# newmont mining shares rise on jump in gold prices
# ['positive'] [ True]
# dec. gold settles at $1,670.80/oz, up $35, or 2.1%
# ['positive'] [ True]
# Gold climbs closer to session highs after U.S. consumer sentiment data
# ['negative'] [False]
# buy crude & gold: kishore narne
# ['positive'] [False]
# gold prices likely to trade on negative note: sushil fin
# ['negative'] [ True]
# gold mostly flat in asia as investors cautious ahead of fed policy views
# ['positive'] [False]
# sharps pixley: gold etf inflows up sharply in april - wgc
# ['none'] [ True]
# gold continues to rise on local demand; silver declines
# ['positive'] [ True]
# Further cut in gold, silver import base price
# ['none'] [False]
# Dec. gold down $15.60, or 1.2%, to settle at $1,253/oz
# ['positive'] [False]
# gold import duty hike not to impact rupee much: stanchart
# ['none'] [ True]
# Weak dollar pushes gold prices to 1-week high
# ['positive'] [ True]
# june gold gains $12.90, or 1%, to $1,302.60/oz
# ['positive'] [ True]
# ray dalio remains focused on gold
# ['positive'] [False]
# April gold jumps $25.30, or 2.1%, to $1,226 an ounce
# ['negative'] [False]
# sharps pixley: russia adds to gold reserves again in march
# ['none'] [ True]
# Gold futures succumb to profit-booking, global cues
# ['negative'] [False]
# Gold futures a tad up at Rs 27,371 per 10 gm
# ['positive'] [ True]
# gold at life-time high of rs 29,695 per 10 grams
# ['positive'] [ True]
# gold climbs back above $400, eyes currency moves
# ['positive'] [ True]
# dec gold up 70c at $426.80/oz in morning ny trade
# ['negative'] [False]
# cil staff to get 2nd shot at ipo gold
# ['none'] [ True]
# spot gold quoted at $537.10 in asia trade
# ['positive'] [ True]
# gold comes off lows but ends in the red
# ['positive'] [False]
# Gold futures fall for the day, but hold onto a weekly gain of 2.4%
# ['negative'] [False]
# philadelphia gold & silver index down 1.51 at 86.20
# ['positive'] [False]
# Gold futures down at Rs 25,244 per 10 gm
# ['negative'] [ True]
# gold weaker, copper down as july china pmi final falls
# ['positive'] [False]
# gold futures briefly top $1,300/oz on comex
# ['positive'] [ True]
# harmony calls for gold fields chairman resignation -rpt
# ['positive'] [False]
# gold marginally down in futures trade on global cues
# ['positive'] [False]
# Gold / Silver / Copper futures - weekly outlook: February 27 - March 3
# ['none'] [ True]
# Gold prices mark highest finish since Sept. 29
# ['positive'] [ True]
# Trump's attack on Gold Star widow raises questions about civilian-military divide
# ['none'] [ True]
# india : bse to launch gold & silver futures from oct 1
# ['none'] [ True]
# feb. gold climbs $4.10 to $652.30/oz in ny
# ['negative'] [False]
# gold futures settle below $1,300 on comex
# ['positive'] [False]
# Gold prices settle at a more than 5-month low
# ['negative'] [ True]
# Gold logs highest settlement since early June, up 0.5% for the week
# ['positive'] [ True]
# Gold futures mark highest finish in more than two weeks
# ['positive'] [ True]
# Gold will shine at &#36;3000 in 2-3 yrs: Superfund Financial
# ['positive'] [ True]
# Gold prices up in Asia as dollar slightly retraces gains from last week
# ['positive'] [ True]
# dec gold falls $3.10 to $496/oz after $500 high overnight
# ['positive'] [False]
# dec. gold closes at its lowest level since july 26
# ['negative'] [ True]
# Gold ETFs smarter option than buying physical gold: NSE
# ['none'] [ True]
# Gold futures prices trade off session lows
# ['negative'] [ True]
# india's gold bar inflows surged 62% in december
# ['none'] [ True]
# Gold gains ground but remains vulnerable
# ['positive'] [ True]
# feb gold at $366.10, up $6.20 after $367.70 high
# ['positive'] [ True]
# Gold prices gain in Asia as dollar trends lower
# ['positive'] [ True]
# record gold high hits markets and jewelers
# ['positive'] [ True]
# february gold adds 0.1% at $1,358.10/oz.
# ['positive'] [ True]
# byu mcx gold feb; target of rs 27845: way2wealth
# ['negative'] [False]
# Gold prices weaker in Asia as investors eye yuan, look to Fed minutes
# ['positive'] [False]
# Gold for December delivery up 0.5% at $1,289.10
# ['positive'] [ True]
# IBJA wants better role for gold industry in GJEPC
# ['none'] [ True]
# dubai gold trade hurt by new indian import tariffs
# ['none'] [ True]
# august gold falls 0.5% to $951.90 an ounce
# ['negative'] [ True]
# Gold edges down as dollar firms up on upbeat US data, Fed comments
# ['negative'] [ True]
# Gold prices in India
# ['none'] [ True]
# gst rate of 3% on gold too low: economic survey
# ['negative'] [ True]
# december gold finishes $8, or 0.7%, lower at $1,115.60 an ounce
# ['negative'] [ True]
# gold ends at record high on weaker stocks, outlook
# ['positive'] [ True]
# gold to trade in 27644-27990 range: achiievers equities
# ['negative'] [False]
# gold takes crude route, sheds over rs 100
# ['negative'] [False]
# gold falls near one-week low
# ['negative'] [ True]
# gold futures lose more ground in late morning dealings
# ['negative'] [ True]
# gold futures end up on bargain buys, econ outlook
# ['positive'] [ True]
# see gold between &#36;1361-1386/oz in near-term: iti
# ['positive'] [False]
# technical view on gold, nickel, copper, silver: nirmal bang
# ['none'] [ True]
# gold prices extend gains on strong technical signals
# ['positive'] [ True]
# charts : gold hangs on to key support level, but buyers have a lot to do still
# ['negative'] [False]
# Gold ETFs register Rs 300 cr outflow in April-August
# ['negative'] [False]
# gold futures close above $460 an ounce
# ['positive'] [False]
# gold price forecast: monthly-high on radar amid string of higher-lows
# ['positive'] [ True]
# Gold up a 4th session in row, settles at a nearly 3-week high
# ['positive'] [ True]
# buy crude at rs 5130/bbl; gold at rs 30850/oz: motilal
# ['positive'] [False]
# gold closes down 3.4%; copper falls 6.5%
# ['none'] [False]
# Tariff value on gold imports cut sharply
# ['positive'] [False]
# spot gold quoted at $382.70, down 0.1% from ny
# ['positive'] [False]
# gold futures close higher for a third session
# ['positive'] [ True]
# Gold tumbles to Rs 30,200; silver falls by Rs 150/kg
# ['negative'] [ True]
# Gold suffers largest weekly loss in more than 3 years
# ['negative'] [ True]
# gold rate: check out current gold price
# ['positive'] [False]
# gold, energy prices help lift canadian stocks
# ['positive'] [ True]
# expert tips to trade gold, crude, nickel & copper
# ['none'] [ True]
# One in five Indians is willing to buy gold even if prices rise
# ['positive'] [ True]
# gold edges up as dollar index slumps to three-year lows
# ['positive'] [ True]
# india's gold buying season not looking as shiny
# ['none'] [ True]
# gold prices post narrow gain in afternoon dealings
# ['positive'] [ True]
# commodities today: here are calls on copper, gold, crude
# ['none'] [ True]
# gold futures score biggest 1-day gain in more than 2 weeks
# ['positive'] [ True]
# 62.32

# %%
#model.predict(vec.transform(['december gold down $1 at $749 an ounce on nymex']))

# %%
import joblib
joblib.dump(model, 'model.pkl')
# Out:
# ['model.pkl']
