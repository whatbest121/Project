# %% [markdown]
# ## Read into Python
#
# Let's first read the required data from CSV file using Pandas library.

# %%
import pandas as pd
import csv
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.utils import shuffle
from sklearn.feature_extraction.text import CountVectorizer
import numpy as np                  #linear algebra
import pandas as pd                 # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt     #For Visualisation
import seaborn as sns               #For better Visualisation
from bs4 import BeautifulSoup       #For Text Parsing

# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv('main.csv')
data = data[['Dates','News','PriceSentiment']]
print(data.shape)
data.head(7)

# %% [markdown]
# Now, show the data how looks like…

# %%
data.isnull().sum()

# %%
data=data.dropna()
data.isnull().sum()
# Out:
# Dates             0
# News              0
# PriceSentiment    0
# dtype: int64

# %%
Sentiment = data['PriceSentiment'].unique()
print(Sentiment)

data.groupby(data['PriceSentiment']).News.count().plot.bar(ylim=0)
plt.show()
# Out:
# ['negative' 'positive' 'none' 'neutral']

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/whatbest/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
import re

stemmer = PorterStemmer()
words = stopwords.words("english")

data['processedtext'] = data['News'].apply(lambda x: " ".join([stemmer.stem(i) for i in re.sub("[^a-zA-Z]", " ", x).split() if i not in words]).lower())

# %%
print(data.shape)
data.head(10)
# Out:
# (9999, 4)
#       Dates                                               News PriceSentiment  \
# 0   28/1/16  april gold down 20 cents to settle at $1,116.1...       negative
# 1   13/9/17          gold suffers third straight daily decline       negative
# 2   26/7/16     Gold futures edge up after two-session decline       positive
# 3   28/2/18  dent research : is gold's day in the sun comin...           none
# 4    6/9/17  Gold snaps three-day rally as Trump, lawmakers...       negative
# 5   16/8/16  Dec. gold climbs $9.40, or 0.7%, to settle at ...       positive
# 6   24/9/13  gold falls by rs 25 on sluggish demand, global...       negative
# 7   23/9/16  Gold futures fall for the session, but gain fo...       positive
# 8  21/10/12  Gold struggles; silver slides, base metals falter        neutral
# 9   16/3/18  april gold holds slight gain, up $2.50, or 0.2...       positive
#
#                                        processedtext
# 0                           april gold cent settl oz
# 1            gold suffer third straight daili declin
# 2                  gold futur edg two session declin
# 3               dent research gold day sun come soon
# 4  gold snap three day ralli trump lawmak reach d...
# 5                            dec gold climb settl oz
# 6            gold fall rs sluggish demand global cue
# 7                  gold futur fall session gain week
# 8        gold struggl silver slide base metal falter
# 9                     april gold hold slight gain oz

# %% [markdown]
# ## Pre-process Data
#
# We need to remove package name as it's not relevant. Then convert text to lowercase for CSV data. So, this is data pre-process stage.

# %%
def preprocess_data(data):
    # Remove package name as it's not relevant
    #data = data.drop('News', axis=1)
    
    # Convert text to lowercase
    data['processedtext'] = data['processedtext'].str.strip().str.lower()
    return data

# %%
data = preprocess_data(data)

# %% [markdown]
# ## Splitting Data
#
# First, separate the columns into dependent and independent variables (or features and label). Then you split those variables into train and test set.

# %%
df = data
# Split into training and testing data
x = data['News']
y = data['PriceSentiment']
x, x_test, y, y_test = train_test_split(x,y, stratify=y, test_size=0.3, random_state=42)

# %% [markdown]
# Vectorize text reviews to numbers.

# %%
# Vectorize text reviews to numbers
vec = CountVectorizer(stop_words='english')
x = vec.fit_transform(x).toarray()
x_test = vec.transform(x_test).toarray()

# %% [markdown]
# ## Model Generation
#
# After splitting and vectorize text reviews to number, we will generate a random forest model on the training set and perform prediction on test set features.

# %%
from sklearn.naive_bayes import MultinomialNB

model = MultinomialNB()
model.fit(x, y)
# Out:
# MultinomialNB()

# %% [markdown]
# ## Evaluating Model
#
# After model generation, check the accuracy using actual and predicted values.

# %%
model.score(x_test, y_test)*100
# Out:
# 76.06666666666668

# %% [markdown]
# Then check prediction…

# %%
from itertools import count
import pandas as pd
df = pd.read_csv('gold-dataset-sinha-khandait.csv', sep=',', header=None)
start = 10000
end = 10570
df = df[start - 1:end - 1]
correct = 0
for i in range(len(df)):
    print(df.values[i][2])
    print(model.predict(vec.transform([df.values[i][2]])),df.values[i][9] == model.predict(vec.transform([df.values[i][2]])))
    
    if df.values[i][9] == model.predict(vec.transform([df.values[i][2]])):
        correct += 1
        
print(correct / len(df) * 100 )
# Out:
# Kerala govt studying tax reduction on gold
# ['none'] [ True]
# gold gets a festive lift, tops rs 31,000-mark
# ['positive'] [ True]
# gold ends at new record high of $837.50 an ounce on nymex
# ['positive'] [ True]
# Gold futures prices trade near the session's lows on Comex
# ['negative'] [ True]
# gold settles at a more than 1-week high as dollar softens ahead of fed decision
# ['positive'] [ True]
# Gold prices mark first climb in 7 sessions
# ['positive'] [ True]
# Gold investment demand falls 34%, but WGC says it was still 'robust'
# ['none'] [ True]
# gold futures end higher, but post a weekly decline
# ['positive'] [ True]
# Gold perched at $1,200 ahead of US jobs report
# ['negative'] [False]
# Gold futures down at Rs 28,396 per 10 gm
# ['positive'] [False]
# gold futures for dec. delivery down $22.70-ounce
# ['positive'] [False]
# mcx goldm april contract advances
# ['positive'] [ True]
# Gold rebounds from 3-month lows to finish higher
# ['positive'] [ True]
# illegal flow of gold to nepal from india across porous border showing upward swing
# ['none'] [ True]
# Dec. gold loses $3, or 0.2%, to settle at $1,332.70/oz
# ['negative'] [ True]
# gold holds steady as investors brace for greece default on debt payments
# ['neutral'] [ True]
# gold prices at 1-week lows as dollar remains supported
# ['negative'] [False]
# gold futures close with strong gains
# ['positive'] [ True]
# Gold holds loss after Chicago PMI
# ['negative'] [ True]
# gold dips on draghi comments, through erases earlier losses
# ['negative'] [ True]
# Gold futures at two-week high as the dollar weakens
# ['positive'] [ True]
# gold futures log a loss of nearly $24 an ounce
# ['negative'] [ True]
# India gold extends rise to over 2-mth high
# ['positive'] [ True]
# Gold at 8-month low: Should you start your festive buying early?
# ['positive'] [False]
# gold prices steady in early asia trade with focus on hong kong
# ['positive'] [False]
# gold prices slip as surging u.s. treasury yields lift dollar
# ['negative'] [ True]
# gold adds 0.7% to trade at record $1,601.50/oz
# ['positive'] [ True]
# Gold continues slide on muted demand, global cues
# ['negative'] [ True]
# gold ends back above $1,690 on safe-haven appeal
# ['positive'] [ True]
# gold, silver rise further on global bullishness
# ['positive'] [ True]
# gold loses sheen on muted demand, silver also eases
# ['negative'] [ True]
# comex gold marks highest settlement since aug. 21
# ['positive'] [ True]
# Gold futures end the week with a gain of about 0.2%
# ['positive'] [ True]
# Gold books a loss as stocks, dollar rally
# ['negative'] [ True]
# gold end at best in six weeks; silver 1.9% higher
# ['positive'] [ True]
# Gold prices dip in Asia, but supported by Ukraine events
# ['positive'] [False]
# mcx goldguinea june contract gains
# ['positive'] [ True]
# gold falls to two-month low as oil tumbles
# ['negative'] [ True]
# gold, oil keep losses after factory orders data
# ['negative'] [ True]
# cboe gold index closes at 133.33, down 0.2%
# ['positive'] [False]
# dec. gold futures up $4.50 at $425.30
# ['negative'] [False]
# gold hits 3-week low; strong dollar, fed rate hike view weigh
# ['negative'] [ True]
# why gold and silver are in the dumps
# ['none'] [False]
# gold hits 23-month low at rs 25,650 on weak global cues
# ['negative'] [ True]
# spot gold quoted at $412.90, down 60c from new york
# ['positive'] [False]
# china sends gold prices soaring
# ['positive'] [ True]
# Gold erases loss to end in positive territory as stocks lose steam
# ['positive'] [ True]
# dow hits record high, while gold and oil futures plumb multi-year lows
# ['positive'] [ True]
# gold, copper extend rallies, set new highs
# ['positive'] [ True]
# Gold prices tumble $12.20, or 1%, to $1,277 an ounce
# ['negative'] [ True]
# india gold demand sluggish as rupee slide supports price
# ['negative'] [False]
# gold demand in india sluggish as price hardens
# ['none'] [ True]
# gold futures advance past $1,360 an ounce
# ['positive'] [ True]
# europeans see more value in gold compared to north americans - mcewen
# ['none'] [ True]
# Gold futures edge up in electronic trade vs. settlement after FOMC minutes
# ['negative'] [False]
# June gold up $5, or 0.4%, at $1,229.40/oz.
# ['positive'] [ True]
# metals focus : rising silver prices outperforming gold
# ['positive'] [False]
# gold futures jump 1% ahead of russia-ukraine talks
# ['positive'] [ True]
# Gold prices dip in Asia, few demand cues seen from India, China
# ['negative'] [ True]
# Gold holds steady as investors turn cautious ahead of French polls
# ['neutral'] [ True]
# Gold prices turn modestly lower as ICE U.S. Dollar Index nears session highs
# ['negative'] [ True]
# gold etfs see rs 539 cr outflows in april-sep fy'17
# ['none'] [ True]
# Gold jumps to Rs 29,700 on firm global cues, spot demand
# ['positive'] [ True]
# gold near seven-and-a-half months high on safe-haven demand
# ['positive'] [ True]
# Dec. gold settles at $1,279.40/oz, down $25.10, or 1.9%
# ['positive'] [False]
# gold prices to move higher towards 30250 levels: choice equity
# ['positive'] [ True]
# gold ends at a 4 1/2-month low as bitcoin soars, u.s. stocks climb
# ['positive'] [False]
# ghana : over 1000 jobs to be created as pmmc constructs gold refinery
# ['none'] [ True]
# gold, silver may trade on rangebound note:angel commodities
# ['positive'] [False]
# MCX GOLDPETAL Oct contract down marginally
# ['positive'] [False]
# gold heads for biggest weekly loss since may
# ['negative'] [ True]
# april gold up $1.90 to settle at $1,372.40/oz
# ['negative'] [False]
# gold, silver reclaim on high stockist demand, global cues
# ['positive'] [ True]
# crude oil up, gold down after spending data
# ['negative'] [ True]
# could the stars be aligned for $1,500 gold?
# ['positive'] [False]
# rbi has advised against selling gold coins: fm chidambaram
# ['none'] [ True]
# Gold falls to Rs 29,300; silver down at Rs 39,150
# ['negative'] [ True]
# february gold down $11.30, or 0.9%, at $1,327.40/oz.
# ['positive'] [False]
# gold futures close above $580 an ounce
# ['negative'] [False]
# drdgold, mintails in gold processing joint venture
# ['positive'] [False]
# gold dawdles to end record-breaking year with modest gains
# ['positive'] [ True]
# dec. gold climbs $19, or 2.6%, to $753.20/oz on globex
# ['positive'] [ True]
# gold ends up 0.8% at $934.90 an ounce
# ['positive'] [ True]
# MCX gold opens lower at Rs 29,995 per 10 gm
# ['negative'] [ True]
# gold touches new high overseas, dips a tad here
# ['positive'] [ True]
# Gold gains as Ukraine crisis heats up and softens dollar
# ['positive'] [ True]
# Gold futures decline to Rs 27,600 on profit-booking, global cues
# ['negative'] [ True]
# hsbc lowers 2012 gold forecast 9% to $1,850/oz
# ['negative'] [False]
# Dec. gold settles at $1,331.40/oz, up $13.20, or 1%
# ['negative'] [False]
# feb gold closes at $541.20/oz, up $13.40, or 2.5%
# ['negative'] [False]
# gold futures hit record high of rs 26,960 on global cues
# ['positive'] [ True]
# gold futures edge lower in holiday trading
# ['negative'] [ True]
# gold bounces rs 210 on global cues, buying uptick
# ['positive'] [ True]
# gold inches higher, silver comes off 30-year high
# ['positive'] [ True]
# Gold futures post gain of about 0.7% for the week
# ['positive'] [ True]
# Gold prices steady on festival season demand
# ['positive'] [False]
# cftc : gold speculators sharply added to bullish net positions for 4th week
# ['none'] [ True]
# mcx goldpetal january contract slips
# ['positive'] [False]
# Gold tumbles to Rs 30,100; silver slips below Rs 41K-mark
# ['negative'] [ True]
# spot gold prices trading lower
# ['negative'] [ True]
# gold notches 1.5% gain to close at $949.20 an ounce
# ['positive'] [ True]
# gold sinks 6%; copper hit after china data
# ['negative'] [ True]
# gold futures mark first loss in 5 sessions
# ['negative'] [ True]
# gold at seven-week low; silver, platinum higher
# ['negative'] [ True]
# gold dips, but posts 1% weekly gain
# ['positive'] [ True]
# no gold dhamaka in diwali run-up as gold prices are expected to trade in the rs 26,000-28,500 range
# ['positive'] [ True]
# Gold pares gains slightly after GDP and durable-goods readings
# ['positive'] [ True]
# polyus gold year net rose 57%
# ['none'] [ True]
# mcx goldguinea august contract gains
# ['positive'] [ True]
# Gold near highest in over two months as equity plunge boosts safe-haven appeal
# ['positive'] [ True]
# philadelphia gold and silver index up 1.4% on the month
# ['positive'] [ True]
# Gold Prices Steady on Dollar Weakness as Q3 GDP Cools
# ['positive'] [False]
# dec. gold climbs $2.60 to $630.50/oz in morning trading
# ['positive'] [ True]
# year to date performances disappoint, except for gold
# ['positive'] [False]
# allowing banks to buy back gold could curb imports: sbi
# ['none'] [ True]
# no bullets left for gold
# ['positive'] [False]
# Gold prices end slightly higher, tally third-weekly gain in a row
# ['positive'] [ True]
# Gold futures jump to Rs 28,235 per 10 gm
# ['positive'] [ True]
# feb. gold gains 2.2% for the month
# ['positive'] [ True]
# crude oil down, gold futures up after jobless data
# ['positive'] [ True]
# gold futures close higher on the session
# ['positive'] [ True]
# Gold deepens pullback from 7-week highs; U.S. payrolls data awaited
# ['positive'] [False]
# government slashes import tariff value of gold, silver
# ['none'] [ True]
# spot gold bid at $380.30 an ounce, down $2.20
# ['positive'] [False]
# barrick gold profit slumps 90% amid failed merger
# ['negative'] [False]
# gold ends lower as dollar strengthens
# ['negative'] [ True]
# gold fields, bolivar agree to $330m acquisition plan
# ['none'] [ True]
# gold declines as investors await bernanke
# ['negative'] [ True]
# Simone Biles wins her 4th gold at Rio; Aly Raisman takes silver
# ['none'] [ True]
# gold in two-session gain of $21
# ['positive'] [ True]
# gold, silver slip on lower global cues
# ['negative'] [ True]
# gold bugs brush aside first drop in 13 years
# ['negative'] [ True]
# june gold ends up $13.60 at $926.80 an ounce on nymex
# ['negative'] [False]
# gold up in electronic trade as fed keeps rates steady
# ['positive'] [ True]
# Gold near 5-month highs in risk-off trade
# ['positive'] [False]
# gold up by rs 25, silver by rs 200 on strong demand
# ['negative'] [False]
# forex reserves rise $452m; gold value unchanged
# ['none'] [False]
# Gold futures down at Rs 30,893 per 10 gm
# ['positive'] [False]
# lbma to reveal size of london's gold market on nov. 20
# ['none'] [ True]
# comex gold futures down 10 sessions in a row
# ['negative'] [ True]
# ubs: gold going nowhere anytime soon
# ['none'] [ True]
# gold poised to follow global cues, move within range
# ['positive'] [False]
# Fed's is following a playbook written when gold fled the Nazis
# ['negative'] [False]
# feb gold up 10 cents at $650.70/oz in morning trading
# ['negative'] [False]
# august gold down $7.60, or 0.6%, for the session to settle at $1,323.40/oz
# ['negative'] [ True]
# Gold futures little changed after data
# ['neutral'] [ True]
# sell mcx gold below rs 28400; target 28350:dani commodities
# ['none'] [ True]
# Gold Prices Down In Asia After Regional Data Sets, India Demand In Focus
# ['positive'] [False]
# gold prices sharply weaker in asia as fed signals december rate hike
# ['positive'] [False]
# gold futures end at a three-session high
# ['positive'] [ True]
# Gold little-changed after ECB decision, up $2.00, or 0.2%, at $1,351.20
# ['negative'] [False]
# Gold's early decline holds steady after inflation, personal-spending data
# ['negative'] [False]
# gold prices end lower for a third straight session
# ['negative'] [ True]
# gold funds find favour with investors
# ['none'] [ True]
# gold futures up by rs 91 on firm global cues
# ['positive'] [ True]
# goldman sachs : gold seen rising to us$1,350  in 12 months
# ['none'] [False]
# gold to trade in 28357-29129 range: achiievers equities
# ['neutral'] [ True]
# gold prices turns lower after high near $426
# ['positive'] [False]
# gold ends higher ahead of central bank meetings
# ['positive'] [ True]
# gold slips, silver rises, and stocks trade mixed
# ['positive'] [ True]
# gold imports to pick up from this month: stanchart
# ['none'] [ True]
# april gold falls $10 to $353/oz, lowest close in 4 wks
# ['negative'] [ True]
# India trade body asks members to curb gold coin sales
# ['none'] [ True]
# gold rates: mcx goldm august contract slips
# ['negative'] [ True]
# mcx goldpetal february contract firms up
# ['positive'] [ True]
# feb. gold down $1.70 at $811.80 an ounce on nymex
# ['negative'] [ True]
# gold futures drop as fed policy comes into focus
# ['negative'] [ True]
# gold prices hinges on fears of global recession
# ['negative'] [False]
# india re-rating story, gold to surprise in h2: hans goetti
# ['none'] [ True]
# gold price falls as dollar strengthens
# ['negative'] [ True]
# dec gold futures up $3.70 at $493.20 an ounce
# ['negative'] [False]
# June gold falls $1.70, or 0.1%, to settle at $1,226.90/oz
# ['negative'] [ True]
# world gold council : north american gold-backed etfs dominate in january
# ['none'] [ True]
# india gold seen snapping two-week gains
# ['positive'] [ True]
# feb. gold ends down $27.40 at $1,112.60 an ounce
# ['negative'] [ True]
# gold jumps more than 1% on crisis in ukraine
# ['positive'] [ True]
# a crypto tycoon, banking heir and the mysterious fight for gold
# ['none'] [ True]
# dhanteras in june for gold trade
# ['positive'] [False]
# dec. gold gains $25.30, or 2.2%, to settle at $1,153.20/oz
# ['positive'] [ True]
# gold falls, but nears the day's high on record '05 demand
# ['positive'] [ True]
# aug gold down $3.70 at $425.10/oz after low of $424.50
# ['negative'] [ True]
# gold falls $5 to settle at $1,298.30/oz
# ['negative'] [ True]
# gold prices edge up on terror scare
# ['positive'] [ True]
# gold, silver scale higher on diwali muhurat trade
# ['positive'] [ True]
# Gold futures settle at lowest level since Oct. 24
# ['negative'] [ True]
# Bearish trend may continue in gold
# ['negative'] [ True]
# bad week for commodities: oil, gold, nickel, all take a fall
# ['negative'] [ True]
# Gold gains on Ukraine unrest, weak Chinese output data
# ['positive'] [ True]
# gold rules steady at rs 23,270, silver soars to rs 58,000
# ['positive'] [False]
# Gold Rate Today: Gold rises in futures trade; up 0.54% on global cues
# ['positive'] [ True]
# Gold futures up at Rs 27,336 per 10 gm
# ['negative'] [False]
# gold to trade in 30813-31473 range: achiievers equities
# ['neutral'] [ True]
# Gold surges on fresh buying, silver eases
# ['positive'] [ True]
# Gold Prices Drop on Stronger U.S. Dollar
# ['negative'] [ True]
# Gold falls to one-month low on stronger dollar
# ['negative'] [ True]
# Bitcoin Pares Losses, Bitcoin Gold Plunges 17%
# ['none'] [ True]
# Gold marks highest finish of the month
# ['positive'] [ True]
# comex gold ends higher for fourth session in a row
# ['positive'] [ True]
# gold steady near 7-week highs ahead of us jobs data
# ['positive'] [False]
# gold pulls back; palladium gains
# ['positive'] [False]
# Gold falls to Rs 29,430; silver down at Rs 38,700 per kg
# ['negative'] [ True]
# Gold edges up in electronic trading as Fed stands pat on interest rates
# ['positive'] [ True]
# why new gold bulls have gone extinct
# ['none'] [ True]
# comex gold settles at $1,102/oz, down $19, or 1.7%
# ['negative'] [ True]
# gold futures fall over 1%, tracking drop in crude
# ['negative'] [ True]
# Gold futures close down $2.50, or 0.2%, at $1,274.30/oz.
# ['negative'] [ True]
# Gold futures log highest settlement in almost 13 weeks
# ['positive'] [ True]
# severstal to list nord gold unit on lse thursday
# ['none'] [ True]
# Dec. gold drops $15.50, or 1.2%, to settle at $1,335.70/oz
# ['negative'] [ True]
# Gold futures open marginally lower at Rs 30,598
# ['negative'] [ True]
# Gold holds modest gains after consumer-sentiment, home-sales data
# ['positive'] [ True]
# Gold slips to 2-week low on global cues, muted demand
# ['negative'] [ True]
# gold futures score a 2% gain for the week
# ['positive'] [ True]
# gold gains in delhi
# ['positive'] [ True]
# Dec. gold settles at $1,253.80/oz, down $2.10, or 0.2%
# ['positive'] [False]
# April gold settles at $1,248.50/oz, up $1.30, or 0.1%
# ['negative'] [False]
# Gold prices settle at a more than 2-week low
# ['negative'] [ True]
# April gold off 70 cents, or less than 0.1%, at $1,249.20/0z.
# ['positive'] [False]
# april gold drops $12.70, or 1%, to trade at $1,316.80/oz
# ['negative'] [ True]
# april gold climbs $10 to $1,100/oz on globex
# ['positive'] [ True]
# Gold futures add to slight loss after employment, inflation reports
# ['negative'] [ True]
# gold futures end lower after hitting record high
# ['positive'] [False]
# Dec. gold falls $1, or less than 0.1%, to settle at $1,273.50/oz
# ['negative'] [ True]
# Gold futures open marginally higher
# ['positive'] [ True]
# Gold futures end lower after 5-session climb
# ['negative'] [ True]
# Gold prices extend gains as dollar sags after Donald Trump remarks
# ['positive'] [ True]
# Gold ends lower as havens lose ground after French vote
# ['negative'] [ True]
# gold prices steady to higher in asia as physical demand supports
# ['positive'] [ True]
# Gold climbs towards 3-month peak as equity rout sparks safe-haven rush
# ['positive'] [ True]
# gold futures, metals index reach fresh highs
# ['positive'] [ True]
# spot gold quoted at $418, up $1.10 from new york
# ['positive'] [ True]
# gold prices gain in asia on weaker dollar, trump trade policies eyed
# ['positive'] [ True]
# a 'death cross' is haunting gold
# ['none'] [ True]
# gold higher as irish bailout doesn't quell worries
# ['positive'] [ True]
# Gold falls to 7-week low as rate hike expectations rise
# ['negative'] [ True]
# gold climbs to a two-week high near $1,170
# ['positive'] [ True]
# charts : gold bounces from one-year low but dollar weighs
# ['negative'] [ True]
# gold: 'the upside is wide open'
# ['positive'] [ True]
# Gold settles lower, then edges up in electronic trade after Fed Beige Book
# ['negative'] [False]
# recycled gold in india rises 44.5% to 61.3 tonne: world gold council
# ['none'] [ True]
# italy : will italy sink the eu and boost gold?
# ['negative'] [False]
# amex gold bugs index closes down 2.2% for the week
# ['negative'] [ True]
# gold as good as advertised?
# ['none'] [ True]
# gold, silver extend gains on rising global trend
# ['positive'] [ True]
# gold down 6.3% as selling intensifies pre-settle
# ['negative'] [ True]
# Gold futures off 0.4% at $1,313.60/oz.
# ['positive'] [False]
# HDFC MF launches gold fund
# ['none'] [ True]
# gold prices little changed as dollar holds steady on tax bill hopes
# ['neutral'] [ True]
# next sovereign gold bond issue price fixed at rs 2,961 per gram
# ['none'] [ True]
# gold futures down 40c at $876.80 an ounce
# ['negative'] [ True]
# why now may be a good time to buy gold and silver
# ['none'] [ True]
# gold climbs by rs 330 per ten grams in early trade
# ['positive'] [ True]
# wheaton river board says to reject glamis gold bid
# ['none'] [ True]
# investors chronicle :  gold in recessions
# ['negative'] [False]
# gold prices edge up; mining shares mixed
# ['positive'] [ True]
# Gold ends higher to halt streak of declines
# ['positive'] [ True]
# neutron star mergers may create much of the universe's gold
# ['none'] [ True]
# Gold up by Rs 46 in futures trade on steady demand
# ['positive'] [ True]
# Gold falls as dollar firms up, N. Korea worries ease
# ['negative'] [ True]
# gold settles at lowest in nearly four months
# ['negative'] [ True]
# August gold 0.3% higher at $1,225.90/oz.
# ['positive'] [ True]
# why gold should be a part of your portfolio?
# ['none'] [ True]
# mcx goldpetal jan contract rises
# ['positive'] [ True]
# Gold set to end 2-week rally as dollar firms up
# ['positive'] [False]
# Custom officials seize 7.5kg gold from air passenger
# ['none'] [ True]
# singapore's core exports rise due to gold, chemicals
# ['positive'] [False]
# gold futures gain almost $30 for the week
# ['positive'] [ True]
# Gold futures finish lower ahead of Fed interest-rate decision
# ['negative'] [ True]
# Gold prices hold steady amid subdued dollar
# ['neutral'] [ True]
# Gold futures settle at lowest level in about seven weeks
# ['negative'] [ True]
# Gold snaps 3-day losing streak
# ['negative'] [False]
# dec gold futures close down 40c at $470
# ['negative'] [ True]
# gold falls on u.s. housing data, waning geopolitical tensions
# ['negative'] [ True]
# Gold prices lose over 3% for the week
# ['negative'] [ True]
# gold falls to six-session low
# ['negative'] [ True]
# Gold ends lower as expectations grow for interest-rate hike later this year
# ['negative'] [ True]
# april gold ends up $4.20 at $976 an ounce on nymex
# ['negative'] [False]
# gold marks two-week low on caution ahead of fed policy decision
# ['negative'] [ True]
# gold rises on weaker dollar
# ['positive'] [ True]
# Gold falls to Rs 29,050; silver down at Rs 38,500 per kg
# ['negative'] [ True]
# dec. gold drops $13.50, or 2.3%, to end at $582.90/oz
# ['negative'] [ True]
# gold falls for seventh trading day
# ['negative'] [ True]
# gold dulls but gains on the week
# ['positive'] [ True]
# Speculators haven't been this bullish on gold since October
# ['none'] [ True]
# Gold futures tally 4-session climb to mark highest finish since Sept. 7
# ['positive'] [ True]
# gold closes 1% lower at $1,176.10 an ounce
# ['negative'] [ True]
# Gold prices rally toward $1,300 to finish at a more than 1-month high
# ['positive'] [ True]
# gold extends advance, trades at record
# ['positive'] [ True]
# gold ends higher on senate budget, debt proposal
# ['positive'] [ True]
# dec. gold slides 0.2% to $1,172.10 an ounce
# ['negative'] [ True]
# gold futures up $24.70 at $1,655.50 an ounce
# ['positive'] [ True]
# Gold marks highest finish since late September 2016
# ['positive'] [ True]
# Gold prices turn slightly higher ahead of Comex settlement
# ['positive'] [ True]
# Gold down a third day on dollar strength, with inflation risk in focus
# ['positive'] [False]
# gold futures close lower; palladium climbs
# ['negative'] [ True]
# physical gold buyers sit out this price rout
# ['none'] [ True]
# Gold futures end the session at a nearly two-week high
# ['positive'] [ True]
# April gold off $5.90, or 0.5%, at $1,197.70/oz.
# ['negative'] [ True]
# Gold imports up 4% to $ 17.63 bn in April-September
# ['none'] [ True]
# gold tempers bay street losses
# ['positive'] [False]
# August gold climbs $9.40, or 0.8%, to settle at $1,254.90/oz
# ['positive'] [ True]
# precious metals tumble on concerns over imf gold sale
# ['negative'] [False]
# Gold futures rises to Rs 28,595 on global cues, short-covering
# ['positive'] [ True]
# Dec. gold gains $2.10, or 0.2%, to $1,271.70/oz
# ['positive'] [ True]
# Gold futures jump to Rs 28,959 on firm global cues
# ['positive'] [ True]
# china 's gold reserves rise for 1st time in over two years in dec
# ['positive'] [ True]
# platinum at three-month high on amplats overhaul; gold firm
# ['positive'] [ True]
# Demand for gold on the rise amid uncertainty in global markets
# ['positive'] [False]
# spot gold rises $6.10 to $1,138.80/troy ounce
# ['positive'] [ True]
# gold firms on soft dollar, us fiscal talks eyed
# ['negative'] [False]
# gold hits 1-week high; fed chair pick in focus
# ['positive'] [ True]
# Gold edges up from 1-week ow
# ['positive'] [ True]
# Gold climbs to 2-1/2 week highs on views Fed will hold off on rates
# ['positive'] [ True]
# Gold Rate Today: Gold, silver trade higher
# ['positive'] [ True]
# To curb buying, Govt may raise import duty on gold
# ['none'] [ True]
# if china slows down u.s. debt buying, will gold rally or plunge?
# ['none'] [ True]
# Gold ends at more-than-2-week low
# ['negative'] [ True]
# gold steady on dollar's strength
# ['positive'] [False]
# gold scales new high globally on local demand
# ['positive'] [ True]
# gold rally running on hope
# ['positive'] [ True]
# gold monetisation scheme to be revamped this week: report
# ['none'] [ True]
# gold futures edge lower but remain supported by weaker dollar
# ['negative'] [ True]
# gold stocks end in the red
# ['negative'] [False]
# August gold settles at $1,275.40/oz, up $9.70, or 0.8%
# ['positive'] [ True]
# Gold prices edge higher in Asia with China trade data in focus
# ['positive'] [ True]
# gold investment shift leaves market vulnerable
# ['none'] [ True]
# gold futures accelerate losses
# ['negative'] [ True]
# Gold falls to Rs 31,360; silver down at Rs 40,300
# ['negative'] [ True]
# gold, silver slides called 'overdone'
# ['negative'] [ True]
# Gold futures down at Rs 29,678 per 10 gm
# ['positive'] [False]
# Gold futures decline to Rs 30,384
# ['negative'] [ True]
# gold gains as oil futures slip in early dealings
# ['positive'] [ True]
# dec gold up $2.30 at $408.90 in afternoon ny trade
# ['negative'] [False]
# Gold futures off the highs after U.S. consumer confidence data
# ['positive'] [False]
# gold prices nudge up ahead of fed meeting minutes
# ['positive'] [ True]
# Gold futures remain lower after durables data
# ['negative'] [ True]
# Gold declines 0.4%, sealing first monthly loss since May
# ['negative'] [ True]
# gold importers on sidelines eyeing rupee
# ['none'] [ True]
# gold prices remains on the downside as strong dollar weighs
# ['negative'] [False]
# gold price surge by rs 730 in special diwali mahurat trade on rising demand
# ['positive'] [ True]
# Gold drops 2.5% on equity sell-off, debt fears
# ['negative'] [ True]
# gold futures pare slight gain after comments from fed's clarida, december gold at $1,223/oz.
# ['positive'] [ True]
# gold drops to near 4-month low on year-end selling
# ['negative'] [ True]
# gold falls as drop in equity markets spurs selling
# ['negative'] [ True]
# gold steady ahead of us non-farm payrolls report
# ['neutral'] [ True]
# gold turns negative, retreats to $1,355.50 an ounc
# ['negative'] [ True]
# buy gold -  gold bears press bets in record numbers
# ['none'] [ True]
# gold or silver: which is best safe haven asset?
# ['none'] [False]
# kinross gold upped to 'gold' at ubs
# ['none'] [False]
# gold above $1,400 for best close in over two weeks
# ['positive'] [ True]
# mcx goldpetal jan contract declines
# ['negative'] [ True]
# gold futures mark four-session decline of $6.10/oz
# ['negative'] [ True]
# Gold futures move further above $1,200 ahead of FOMC minutes
# ['negative'] [False]
# Dec. gold drops $42.10, or 3.3%, to settle at $1,224.30/oz
# ['negative'] [ True]
# volatility in gold due to currency: motilal oswal securities ltd
# ['none'] [False]
# December gold rises $11.00, or 0.9%, at $1,328.10/oz
# ['positive'] [ True]
# gold slightly lower as deflation worries continue
# ['negative'] [ True]
# Gold futures touches all-time high
# ['positive'] [ True]
# Dec. gold loses $6.70, or 0.5%, to settle at $1,323.70/oz
# ['negative'] [ True]
# gold is at an all-time high but not for any rational reason
# ['positive'] [ True]
# april gold falls 1.1%, or $7.10, to $637/oz in ny
# ['negative'] [ True]
# silver and gold futures ease on global leads
# ['negative'] [False]
# Gold futures rise to Rs 30,866 per 10 gm
# ['positive'] [ True]
# gold, oil extend losses after cpi, empire survey
# ['negative'] [ True]
# feb. gold ends down $21.70, or 2.5%, at $857.80 an ounce
# ['positive'] [False]
# gold recovers on fresh buying
# ['positive'] [ True]
# No spurt in gold imports after removal of restrictions
# ['none'] [ True]
# Gold ends slightly higher following a recent drop to three-week lows
# ['negative'] [False]
# Gold futures pull back from three-week high, tracking stronger dollar
# ['negative'] [ True]
# philadelphia gold and silver index up 1.7% for the week
# ['positive'] [ True]
# Gold marks highest settlement in a month, up over 2% for the week
# ['positive'] [ True]
# Gold extends gains on sluggish US data, safe-haven demand
# ['positive'] [ True]
# Gold settles at 1-week low on Yellen testimony, U.S. economic growth
# ['negative'] [ True]
# Gold futures end near 4-week high as FBI restarts Clinton email probe
# ['positive'] [ True]
# Gold prices ease in Asia, metals await China retail, industrial data
# ['negative'] [False]
# gold falls below three-month high, amid dwindling consumer sentiment
# ['negative'] [ True]
# u.s. stock futures, gold, crude slip on china data
# ['negative'] [ True]
# gold exchange-traded fund just a click away
# ['none'] [ True]
# Lack of trust in paper currencies should benefit gold, says analyst
# ['none'] [ True]
# gold futures rebound on weak rupee; global cues
# ['negative'] [False]
# gold snaps 6-week winning streak, falls 2.3% for week
# ['negative'] [ True]
# rcm celebrates decades of innovation with anniversary tributes to its gold and silver maple leaf bullion coins
# ['none'] [ True]
# Gold maintains loss after ISM services report
# ['negative'] [ True]
# gold on track for best weekly gain since nov
# ['positive'] [ True]
# Gold prices pare more gains ahead of Comex settlement
# ['positive'] [ True]
# MCX gold in corrective decline
# ['negative'] [ True]
# Gold prices fall in Asia as traders keep close eye on dollar strength
# ['negative'] [ True]
# comex gold logs first gain in four sessions
# ['positive'] [ True]
# philly gold and silver index ends at 99.12, down 0.9%
# ['positive'] [False]
# Gold prices fall for the day, but post a second straight monthly gain
# ['positive'] [ True]
# gold edges higher as fed rate hike bets fade
# ['positive'] [ True]
# december gold futures off $45.70 to $1,762.40 oz
# ['negative'] [False]
# comex gold scores first gain in three sessions
# ['positive'] [ True]
# gold falls rs 86 in futures trade on weak global cues
# ['negative'] [ True]
# Dec. gold settles at $1,277.70/oz, up $5.90, or 0.5%
# ['negative'] [False]
# london daily gold fix being probed: report
# ['none'] [ True]
# Gold slips below Rs 31K on US rate hike talk
# ['negative'] [ True]
# radio update: shine is off sears and gold
# ['positive'] [False]
# Gold futures finish the week with a gain of roughly 1%
# ['positive'] [ True]
# Gold ends higher, but suffers a weekly loss
# ['negative'] [False]
# mcx goldpetal july contract trades higher
# ['positive'] [ True]
# gold buying picks up ahead of festive season in india, china
# ['positive'] [ True]
# dec gold drops $7.40, or 1.7%, to $434/oz in ny
# ['negative'] [ True]
# is gold wrong and oil right on ukraine and russia?
# ['positive'] [False]
# mcx gold, silver prices to trade sideways to positive:angel
# ['positive'] [False]
# mcx goldpetal october declines
# ['negative'] [ True]
# capital economics says gold is going to fall
# ['none'] [False]
# which is a better investment bet, gold or goldï¿½etfs? find out
# ['none'] [ True]
# December gold up 0.3% at $1,282.30 an ounce
# ['positive'] [ True]
# gold closes higher for first time in three sessions
# ['positive'] [ True]
# august gold ends up $4.70, or 0.5%, at $932.20
# ['negative'] [False]
# gold rebounces ahead of akshaya tritiya festival, silver down
# ['none'] [False]
# gold settles at its lowest in over 9 months
# ['negative'] [ True]
# Gold regains momentum on safe haven status
# ['positive'] [ True]
# gold, silver stay on northward course
# ['negative'] [False]
# dec. gold futures down $1.70 at $594.20/ounce
# ['negative'] [ True]
# Gold soars on global cues; silver tumbles
# ['positive'] [ True]
# Gold futures up at Rs 28,490 per 10 gm
# ['positive'] [ True]
# Gold stays near 3-month high amid delayed Fed rate hike hopes
# ['positive'] [ True]
# gold up after weak us jobs data cuts rate hike views
# ['negative'] [False]
# comex gold pares some gains after factory orders data
# ['positive'] [ True]
# Gold futures up by Rs 71
# ['positive'] [ True]
# gold settles 0.7% higher at $1,589.10 an ounce
# ['positive'] [ True]
# gold eases on low buying, silver gains
# ['positive'] [False]
# Gold futures down at Rs 28,436 per 10 gm
# ['negative'] [ True]
# cboe gold index closes at 82.8, down 1.3%
# ['positive'] [False]
# gold jumps to all-time high of rs 34,500 on weak rupee
# ['positive'] [ True]
# s&p: independent bank to replace gold banc on smallcap 600
# ['none'] [ True]
# Support for MCX Gold Oct at Rs 26500: Kotak Commodity
# ['none'] [ True]
# mcx gold prices to trade sideways: angel commodities
# ['positive'] [False]
# Gold Prices<U+202F>Drop<U+202F>On Firmer<U+202F>Dollar<U+202F>   <U+202F>
# ['negative'] [ True]
# gold futures climb to five-week high
# ['positive'] [ True]
# london's gold market demands green credentials for producers
# ['none'] [ True]
# Gold futures fall to Rs 25,275 per 10 gm
# ['negative'] [ True]
# cftc : gold speculators sharply drop bullish bets to lowest in over 2 years
# ['none'] [False]
# August gold down $2.70, or 0.2%, to settle at $1,249.40/oz
# ['positive'] [False]
# gold falls to session low after u.s. durable goods data
# ['negative'] [ True]
# how yellen's gamble screwed up gold
# ['positive'] [False]
# gold up as floor trade reopens, logs october loss
# ['negative'] [False]
# August gold loses $4.30, or 0.3%, to settle at $1,293.20/oz
# ['negative'] [ True]
# gold futures close at their highest level in a month
# ['positive'] [ True]
# gold soars to 2-month high on speculative buying
# ['positive'] [ True]
# December gold down $7.50, or 0.6%, to $1,287.40
# ['negative'] [ True]
# gold gains in asia in buy data day, korea impasse continues
# ['positive'] [ True]
# Why gold buyers are so susceptible to fraud
# ['positive'] [False]
# Gold futures ease to Rs 29,130 per 10 gm
# ['negative'] [ True]
# Gold futures decline to Rs 28,615 per 10 gm
# ['negative'] [ True]
# gold futures up $2.50 at $1,131.90 an ounce
# ['negative'] [False]
# why you shouldn't be selling gold
# ['negative'] [False]
# Gold prices ease in Asia on profit taking, Ukraine events eyed
# ['negative'] [False]
# dec. gold up $11 at $1,157.80/oz after $1,159 high
# ['positive'] [ True]
# charts : gold 7-year bear market phase is over
# ['none'] [False]
# banque de france : removing the cloak from gold
# ['none'] [ True]
# gold prices lower ahead of auction
# ['negative'] [ True]
# Gold settles lower as accelerated Fed hike pace prospects rise
# ['positive'] [False]
# aug. gold settles at $1,173.60/oz on comex, up $5.50, or 0.5%
# ['negative'] [False]
# point72 : nobody is paying much attention to gold for now
# ['none'] [ True]
# gold, silver rise in morning trade
# ['positive'] [ True]
# Gold may rebound in the medium term
# ['positive'] [ True]
# gold, oil extend to gains after ism services data
# ['positive'] [ True]
# gold futures falls, but copper rises
# ['negative'] [ True]
# gold futures add to gains after ism, housing data
# ['positive'] [ True]
# comex gold settles higher for a second straight session
# ['positive'] [ True]
# copper futures head for a four-session loss; gold declines
# ['negative'] [ True]
# Gold holds slight loss, but mostly flat, after housing-starts data
# ['negative'] [ True]
# Gold Prices Edge Slightly Higher, Gains Capped
# ['positive'] [ True]
# rbc : gold is ignoring its usual headwinds
# ['none'] [ True]
# gold futures up 0.1% at $1,186.60 an ounce
# ['positive'] [ True]
# gold pushes back above $1,200; copper jumps
# ['positive'] [ True]
# cboe gold index closes at 97.03, down 1.8%
# ['positive'] [False]
# August gold down $7.70, or 0.6%, at $1,285.60/oz.
# ['positive'] [False]
# dollar to decide the course of gold from hereon
# ['negative'] [False]
# expect gold, silver to trade on a positive note: angel
# ['positive'] [ True]
# Spot gold edges down to $1,251
# ['positive'] [False]
# demand : bear-market low for new gold investing
# ['negative'] [ True]
# gold ends modestly down; silver, palladium higher
# ['positive'] [False]
# gold prices rise on global rally, silver drops
# ['positive'] [ True]
# December gold down 70 cents at $1,287.10 an ounce
# ['negative'] [ True]
# Gold futures succumb to profit-booking, global cues
# ['negative'] [False]
# dhanteras: demand slump dampens festival; gold fever cools down
# ['none'] [False]
# bema gold shares hit 52-wk high ahead of russia results
# ['positive'] [ True]
# gold : safe haven turns speculative
# ['positive'] [False]
# germany displays its repatriated gold bullion reserves
# ['none'] [ True]
# december gold up $10.50 at $781.50 an ounce on nymex
# ['negative'] [False]
# gold climbs to new high, silver slips
# ['positive'] [ True]
# gold under $1,000 an ounce? don't rule it out says goldman sachs
# ['none'] [ True]
# gold adds to gains, up $35 an ounce
# ['positive'] [ True]
# stocks poised to keep outperforming gold: citi's levkovich
# ['positive'] [False]
# bullionvault : short covering in gold market 'could see $1300' as fed's 2019 rate hikes hit equities, commodities
# ['none'] [ True]
# dec. gold falls 40 cents to $646.50/oz in morning trading
# ['negative'] [ True]
# gold inches lower; fed chair hearing, us tax reforms in focus
# ['negative'] [ True]
# sharps pixley: china's h1 gold output falls 7.9%, but demand rises
# ['none'] [ True]
# spot gold quoted at $465.20 in asia trade
# ['positive'] [ True]
# Huge gold discovery-astronomers can confirm how precious metals were formed
# ['none'] [ True]
# mcx gold has resistance at rs 31200: nirmal bang
# ['none'] [ True]
# after gold, silver proves its mettle in local markets
# ['positive'] [False]
# gold continues slide amid positive greek developments, mixed u.s. data
# ['negative'] [ True]
# silver tumbles by rs 5,500, gold down by rs 300 on global cues
# ['negative'] [ True]
# Global gold prices tumble to 5-year low as dollar strengthens
# ['negative'] [ True]
# april gold futures up $5.20 at $665.20/ounce
# ['negative'] [False]
# gold jewellery exports likely to dip by 50% in fy14: industry
# ['none'] [ True]
# gold ends higher, but posts weekly decline
# ['positive'] [False]
# gold futures turn lower as dollar firms
# ['negative'] [ True]
# gold bugs brace, as metal tests $1,000 again
# ['none'] [False]
# MCX GOLD Dec contract up slightly
# ['positive'] [ True]
# comex gold gains a bit more after u.s. ism data
# ['positive'] [ True]
# Dec. gold settles at $1,290.40/oz, down $3.60, or 0.3%
# ['positive'] [False]
# Gold futures lose more ground, pushing weekly loss to more than 5%
# ['negative'] [ True]
# Gold marks lowest finish in nearly 8 weeks
# ['negative'] [ True]
# April gold climbs $10.70, or 0.9%, to $1,244.70/oz
# ['positive'] [ True]
# dec gold futures end up $3.30 at $489.50 an ounce
# ['positive'] [ True]
# miners help pace europe on m&a, higher gold
# ['positive'] [ True]
# world's reaching peak gold output; prices may soon hit $1,400
# ['none'] [False]
# Gold marks highest finish since mid-November
# ['positive'] [ True]
# gold prices rise further
# ['positive'] [ True]
# Gold edges off one-week low as Greece news knocks stocks
# ['negative'] [ True]
# MCX gold may open lower at Rs 29,050/10 gm
# ['negative'] [ True]
# gold imports hit 125 tonnes in march
# ['none'] [ True]
# gold rebounds; oil falls below $99
# ['negative'] [ True]
# buy gold, copper from short-term perspective: aditya birla
# ['none'] [ True]
# gold futures head higher after three-session drop
# ['positive'] [ True]
# April gold off 0.9% at $1,242.40/oz.
# ['positive'] [False]
# Dec. gold falls $7, or 0.6%, to settle at $1,266.60/oz
# ['negative'] [ True]
# china's gold supply deficit widens over jan-sept
# ['none'] [ True]
# Going for gold
# ['none'] [ True]
# April gold settles at $1,226.50/oz, down 0.5% for the day, 2.5% lower for the week
# ['negative'] [ True]
# Gold finishes at 10-month low on Fed-induced dollar rally
# ['negative'] [ True]
# gold futures fall for a second straight session
# ['negative'] [ True]
# Gold prices hold steady in early Asia with demand cues awaited
# ['positive'] [False]
# Gold ends sharply higher, then holds gains after Fed meeting minutes
# ['positive'] [ True]
# Gold falls by Rs 100 on weak demand; silver recovers
# ['negative'] [ True]
# mcx goldm february contract gains
# ['positive'] [ True]
# gold rises for second day as dollar resumes decline
# ['positive'] [ True]
# gold futures edge higher after ecb rate decision
# ['positive'] [ True]
# bad for stocks, good for gold?
# ['none'] [ True]
# Gold gains after weekly loss, but stays under key $1,350 level
# ['positive'] [ True]
# dec. gold climbs $2.20 to $1,091.50/oz on globex
# ['positive'] [ True]
# Gold prices add to slight decline after PPI
# ['positive'] [False]
# china set to overtake india in gold imports this year: world gold council
# ['none'] [ True]
# cash crunch forces villagers to recycle old gold
# ['none'] [ True]
# Gold slips further on selling pressure
# ['negative'] [ True]
# gold futures end sharply lower, as dollar rallies
# ['negative'] [ True]
# newmont mining upped at merrill, gold price seen higher
# ['none'] [False]
# gold futures continue higher in last half hour of trade
# ['positive'] [ True]
# Weak rupee supports MCX-gold
# ['negative'] [False]
# april gold ends at the lowest level in two months
# ['negative'] [ True]
# April gold falls 90 cents, or less than 0.1%, to end at $1,235.90/oz
# ['negative'] [ True]
# June gold falls $5.90, or 0.5%, to settle at $1,252.80/oz
# ['negative'] [ True]
# gold import dips 47% to 402 tonnes in 2008
# ['none'] [ True]
# gold prices narrowly lower, still trading above $405
# ['negative'] [ True]
# gold closes at a two-month low, down 2% on week
# ['negative'] [ True]
# june gold climbs $11, or 1.7%, to close at $648.50/oz
# ['positive'] [ True]
# Gold's tempered climb makes gains more 'sustainable', says Milling-Stanley
# ['positive'] [ True]
# turkey's attempt to mop up mattress gold
# ['negative'] [False]
# June gold less than 0.1% higher at $1,289.10/oz.
# ['positive'] [ True]
# why rbc says to hedge current market volatility with top gold stocks
# ['none'] [ True]
# How far can gold rally from here?
# ['positive'] [False]
# August gold declines $8, or 0.6%, at $1,285.20/oz.
# ['negative'] [ True]
# gold reversal buoys bay street
# ['positive'] [False]
# commodity outlook: gold may find it tough to top 30,920 level
# ['positive'] [False]
# gold fields up 4.6% at $14.08 premarket
# ['none'] [False]
# gold reverses gains, down 0.1% to $963.10 an ounce
# ['positive'] [False]
# Gold bounces off 5-1/2-month low on physical buying
# ['negative'] [False]
# Gold prices end the first half of the year roughly 7.9% higher
# ['positive'] [ True]
# mcx goldguinea feb contract trading lower
# ['negative'] [ True]
# gold gains in asia, copper jumps as china pmi surveys mixed
# ['positive'] [ True]
# February gold up $3.70, or 0.3%, at $1,134.40/oz.
# ['positive'] [ True]
# gold seen falling from 3-week high this week
# ['positive'] [False]
# dominic frisby : now looks like a good time to buy gold - but you need to watch this chart
# ['none'] [False]
# Gold heading for worst week since November on rate hike worries
# ['negative'] [ True]
# 74.91228070175438

# %%
model.predict(vec.transform(['Changes in non-farm payrolls increase.']))
# Out:
# array(['none'], dtype='<U8')

# %% [markdown]
# Average hourly earnings, m/m, remain unchanged. รายได้เฉลี่ยต่อชั่วโมง m/m ยังคงไม่เปลี่ยนแปลง
# The change in non-farm payrolls increased from the previous time. การเปลี่ยนแปลงในการจ้างงานนอกภาคเกษตรเพิ่มขึ้นจากครั้งก่อน
# lower unemployment rate อัตราการว่างงานลดลง

# %%
import joblib
joblib.dump(model, 'model.pkl')
# Out:
# ['model.pkl']
